# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## 1.1 Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
# * Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
# * Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
# * Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### 1.1.1 Choose your Data
#
# **Datasets corresponding to rainfall information:**
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
# * [`rainfall-monthly-highest-daily-total.csv`](./data/rainfall-monthly-highest-daily-total.csv): The highest daily total rainfall for the month recorded
# * [`relative-humidity-monthly-mean`](./data/relative-humidity-monthly-mean.csv): The monthly mean relative humidity recorded
# * [`SurfaceAirTemperatureMonthlyMeanDailyMaximum`](./data/SurfaceAirTemperatureMonthlyMeanDailyMaximum.csv): The monthly mean daily minimum temperature recorded at the Changi Climate Station
# * [`surface-air-temperature-monthly-mean-daily-minimum`](./data/surface-air-temperature-monthly-mean-daily-minimum.csv): The monthly mean daily maximum temperature recorded at the Changi Climate Station
# * [`SurfaceAirTemperatureMonthlyAbsoluteExtremeMaximum`](./data/SurfaceAirTemperatureMonthlyAbsoluteExtremeMaximum.csv): The monthly extreme maximum air temperature recorded at the Changi Climate Station
# * [`SurfaceAirTemperatureMonthlyAbsoluteExtremeMinimum`](./data/SurfaceAirTemperatureMonthlyAbsoluteExtremeMinimum.csv): The absolute extreme minimum air temperature recorded at the Changi Climate Station
# * [`sunshine-duration-monthly-mean-daily-duration`](./data/sunshine-duration-monthly-mean-daily-duration.csv): The monthly mean sunshine hours in a day recorded at the Changi Climate Station
#
# **Datasets corresponding to Air Quality:**
# * [`air-pollutant-ozone`](./data/air-pollutant-ozone.csv): Annual daily maximum 8-hr means for ozone (µg/m3)
# * [`air-pollutant-particulate-matter-pm2-5`](./data/air-pollutant-particulate-matter-pm2-5.csv): Annual means for PM2.5 (µg/m3)
# * [`AirPollutantParticulateMatterPM10`](./data/AirPollutantParticulateMatterPM10.csv): Annual 24-hr means (99th percentile) for PM10 (µg/m3)
# * [`AirPollutantCarbonMonoxide2ndMaximum8HourMean`](./data/AirPollutantCarbonMonoxide2ndMaximum8HourMeancsv): Annual maximum 8-hr means for carbon monoxide (mg/m3) are based on WHO Air Quality Guidelines (for Europe, 2000).
# * [`AirPollutantNitrogenDioxide`](./data/AirPollutantNitrogenDioxide.csv): Annual means for nitrogen dioxide (µg/m3)
# * [`AirPollutantSulphurDioxide`](./data/AirPollutantSulphurDioxide.csv): Annual means for sulphur dioxide (µg/m3)
# * [`historical-24-hr-psi`](./data/historical-24-hr-psi.csv): Historical regional 24-hr PSI
#
# ---

# %% [markdown]
# ## 1.2 Problem Statement

# %% [markdown]
# ### 1.2.1 Context
# Ongoing climate change, the return of El Nino and La Nina events, recurrent transboundary Southeast Asian Haze. These are some of the major factors that have caused notable shifts in weather patterns. This phenomenon has been apparent in 2023, where we have been experiencing erratic weather variations in Singapore, including heavy rainfall and heatwaves. As such, Air Quality is increasingly a topic of concern. The increased frequency and intensity of extreme weather events contribute to higher levels of air pollutants, including particulate matter (PM2.5 and PM10), nitrogen dioxide (NO2), sulfur dioxide (SO2), and ozone (O3).<br>
# ### 1.2.2 Problem Statement
# You are part of the National Environment Agency (NEA) taskforce set up to develop a set of air quality early warning systems to predict potential periods of air quality deterioration, allowing the government to take necessary precautionary action. As such, your EDA should provide insights to the impact (immediacy, magnitude) that the various weather factors have on air quality.<br><br>
# **Some guiding questions to address:**
# * How are weather conditions, including temperature, humidity, wind patterns, and rainfall, related to each other?
# * How do the various weather conditions affect the various air pollutants?
# * Which pollutants fail to meet NEA's target levels, or are at risk of exceeding ideal levels if erratic weather conditions occur?
# * Which weather conditions could potentially help in preducting air quality movements?
#
# ---

# %% [markdown]
# ## 1.3 Outside Research

# %% [markdown]
# *Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. Make sure that you cite your sources.*<br>
#
# Research has shown that current weather phenomena have significant impacts on air quality. For instance, studies have demonstrated that temperature inversions, prevalent during stagnant weather conditions, can trap pollutants near the surface, leading to higher concentrations and poorer air quality. Additionally, research has explored the effects of rain versus hot weather on air quality. Rainfall has been found to play a beneficial role by removing pollutants through wet deposition, resulting in improved air quality. On the other hand, hot weather conditions can exacerbate the formation of secondary pollutants like ozone, leading to increased pollution levels.
#
# In response to these challenges, Singapore has implemented a multi-pronged approach of "integrated urban and industrial planning, together with development control', along with additional measures such as "legislation, strict enforcement programmes, and air quality monitoring". Furthermore, Singapore has set ambitious targets for air quality improvement. In July 2010, the Advisory Committee on Ambient Air Quality recommended a set of air quality targets for Singapore - year 2020, in alignment with World Health Organization's guidelines.
#
# <img src="../images/NEA Air Quality Targets.png" alt="drawing" width="700"/>
#
# [Image: Singapore Ambient Air Quality Targets](https://www.nea.gov.sg/our-services/pollution-control/air-pollution/air-quality)

# %% [markdown]
# **Sources**<br>
# 1. https://www.nea.gov.sg/our-services/pollution-control/air-pollution/air-quality
# 3. https://www.todayonline.com/singapore/explainer-erratic-weather-heatwave-what-do-extreme-changes-ahead-2172341
# 4. https://www.straitstimes.com/asia/experts-call-for-uniform-air-quality-indicator-in-asean-ahead-of-transboundary-talks-in-s-pore
# 5. https://www.haze.gov.sg/docs/default-source/faq/computation-of-the-pollutant-standards-index-(psi).pdf
#
#
# ---

# %% [markdown]
# ## 1.4 Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Defining function that calculates mean
def calc_mean(values):
    return sum(values)/len(values)

# %%
#Hard code:
def calc_mean(values):
    total = 0
    count = 0

    for value in values:
        total += value
        count += 1

    return total / count

# %%
# To test if function works
mean_val = calc_mean([5,4,3])
mean_val
# Out:
# 4.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Defining function that calculates standard deviation
def std_dev(values):

#calculate squared differences and place them in list
    squared_diff = []

    for value in values:
        squared_diff.append((value - mean_val)**2)

#calculate variance = avg of squared differences
    variance = sum(squared_diff) / len(values)

#calculate std_dev = sq rt of variance
    import math
    return math.sqrt(variance)

# %%
#Hard code:
def std_dev(values):
    # Calculate the mean
    mean_val = 0
    count = 0

    for value in values:
        mean_val += value
        count += 1

    mean_val /= count

    # Calculate squared differences and place them in a list
    squared_diff = []

    for value in values:
        squared_diff.append((value - mean_val) ** 2)

    # Calculate the variance as the average of squared differences
    variance = 0
    for diff in squared_diff:
        variance += diff

    variance /= count

    # Calculate the standard deviation as the square root of the variance
    std_dev = 0
    for diff in squared_diff:
        std_dev += diff

    std_dev /= count
    std_dev = std_dev ** 0.5

    return std_dev

# %%
# To test if function works
std_dev([5, 4, 3])
# Out:
# 0.816496580927726

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.1 Strategies

# %% [markdown]
# ### 2.1.1 Data Import Strategy:
# To make things more organised, I will be importing data in 2 batches -  1) Weather-related, 2) Air Quality related. Within these 2 batches, I have decided to combine the dataframes where possible, if there are common identifier variables between the dataframes that I can use to merge.
#
# ### 2.1.2 Data Cleaning Strategy:
# The usual data cleaning of checking for shape, data types, missing values and duplicates are done.
# As most of the data came from the same source: data.gov.sg, data was easy to clean with little or no null values. Most NEA-sourced data (for the weather conditions and air pollutants) involved data collected from a similar period, with similar date-time formatting. <br><br>

# %% [markdown]
# **General steps for data import and cleaning**<br>
# 1.  Display the data: print the first 5 rows of each dataframe.
# 2.  Check for missing values and datatype, fix errors.
# 3.  Fix any incorrect data types.
# 4.  Rename Columns.
# 5.  Drop unnecessary rows (if needed).
# 6.  Merge dataframes that can be merged.
# 7.  Perform any additional cleaning necessary.
# 8.  Save cleaned and merged dataframes as csv files.

# %% [markdown]
# ## 2.2 Data Import and Cleaning

# %% [markdown]
# ### 2.2.1 Weather Data Import
# This section covers the import and data cleaning of 9 csv files on different weather conditions. Since the files are of similar time granularity, we could merge the files easily. Files were also generally clean with little to no missing data.

# %% [markdown]
# ---
# Import weather data:

# %%
# Bring in weather data
rainf_rain_days = pd.read_csv(r'..\data\rainfall-monthly-number-of-rain-days.csv')
rainf_total = pd.read_csv(r'..\data\rainfall-monthly-total.csv')
rainf_daily_high = pd.read_csv(r'..\data\rainfall-monthly-highest-daily-total.csv')
humi_mean = pd.read_csv(r'..\data\relative-humidity-monthly-mean.csv')
temp_min = pd.read_csv(r'..\data\surface-air-temperature-monthly-mean-daily-minimum.csv')
temp_max = pd.read_csv(r'..\data\SurfaceAirTemperatureMonthlyMeanDailyMaximum.csv')
sunsh_duratn = pd.read_csv(r'..\data\sunshine-duration-monthly-mean-daily-duration.csv')
temp_abs_max = pd.read_csv(r'..\data\SurfaceAirTemperatureMonthlyAbsoluteExtremeMaximum.csv')
temp_abs_min = pd.read_csv(r'..\data\SurfaceAirTemperatureMonthlyAbsoluteExtremeMinimum.csv')

# %% [markdown]
# ---
# Write a function to do the following for each set of weather data:
# * print shape of dataframe
# * convert month to datetime datatype
# * print info
# * print head to check

# %%
def df_inspectn(df):
    df['month'] = pd.to_datetime(df['month'], format='%Y-%m')
    shape = df.shape
    info = df.info()
    head = df.head()
    
    print(shape)
    print(info)
    return df.head()

# %% [markdown]
# ---
# Use the above function to inspect all the weather dataframes:

# %%
#Inspect the rainf_rain_days data
df_inspectn(rainf_rain_days)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             488 non-null    datetime64[ns]
#  1   no_of_rainy_days  488 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 7.8 KB
# (488, 2)
# None
#        month  no_of_rainy_days
# 0 1982-01-01                10
# 1 1982-02-01                 5
# 2 1982-03-01                11
# 3 1982-04-01                14
# 4 1982-05-01                10

# %%
#Inspect the rainf_total data
df_inspectn(rainf_total)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           488 non-null    datetime64[ns]
#  1   total_rainfall  488 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.8 KB
# (488, 2)
# None
#        month  total_rainfall
# 0 1982-01-01           107.1
# 1 1982-02-01            27.8
# 2 1982-03-01           160.8
# 3 1982-04-01           157.0
# 4 1982-05-01           102.2

# %%
#Inspect the rainf_daily_high data
df_inspectn(rainf_daily_high)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      497 non-null    datetime64[ns]
#  1   maximum_rainfall_in_a_day  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  maximum_rainfall_in_a_day
# 0 1982-01-01                       36.5
# 1 1982-02-01                        9.4
# 2 1982-03-01                       61.7
# 3 1982-04-01                       45.1
# 4 1982-05-01                       33.0

# %%
#Inspect the humi_mean data
df_inspectn(humi_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    497 non-null    datetime64[ns]
#  1   mean_rh  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  mean_rh
# 0 1982-01-01     81.2
# 1 1982-02-01     79.5
# 2 1982-03-01     82.3
# 3 1982-04-01     85.9
# 4 1982-05-01     83.2

# %%
#Inspect the temp_min data
df_inspectn(temp_min)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                497 non-null    datetime64[ns]
#  1   temp_mean_daily_min  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  temp_mean_daily_min
# 0 1982-01-01                 23.3
# 1 1982-02-01                 23.9
# 2 1982-03-01                 24.3
# 3 1982-04-01                 24.3
# 4 1982-05-01                 25.2

# %%
#Inspect the temp_max data
df_inspectn(temp_max)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                497 non-null    datetime64[ns]
#  1   temp_mean_daily_max  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  temp_mean_daily_max
# 0 1982-01-01                 29.8
# 1 1982-02-01                 32.3
# 2 1982-03-01                 31.7
# 3 1982-04-01                 31.4
# 4 1982-05-01                 31.7

# %%
#Inspect the sunsh_duratn data
df_inspectn(sunsh_duratn)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              497 non-null    datetime64[ns]
#  1   mean_sunshine_hrs  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  mean_sunshine_hrs
# 0 1982-01-01                5.6
# 1 1982-02-01                7.6
# 2 1982-03-01                5.1
# 3 1982-04-01                4.7
# 4 1982-05-01                5.8

# %%
#Inspect the temp_abs_max data
df_inspectn(temp_abs_max)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   month            497 non-null    datetime64[ns]
#  1   max_temperature  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  max_temperature
# 0 1982-01-01             31.9
# 1 1982-02-01             34.3
# 2 1982-03-01             34.3
# 3 1982-04-01             33.2
# 4 1982-05-01             32.9

# %%
#Inspect the temp_abs_min data
df_inspectn(temp_abs_min)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              497 non-null    datetime64[ns]
#  1   temp_extremes_min  497 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB
# (497, 2)
# None
#        month  temp_extremes_min
# 0 1982-01-01               21.9
# 1 1982-02-01               22.6
# 2 1982-03-01               22.3
# 3 1982-04-01               22.2
# 4 1982-05-01               23.7

# %% [markdown]
# ---
# Merging all the above dataframe into one single dataframe. This step is straightforward as the dataframes all share the same month column:

# %%
#merge the tables on the 'month' column
weather = pd.merge(left = rainf_rain_days,
                          right = rainf_total,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = rainf_daily_high,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = humi_mean,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = temp_min,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = temp_max,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = sunsh_duratn,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = temp_abs_max,
                          how = 'left',
                          on = "month")

# %%
weather = pd.merge(left = weather,
                          right = temp_abs_min,
                          how = 'left',
                          on = "month")

# %%
#Check merged weather table
print(weather.shape)
weather.head()
# Out:
# (488, 10)
#        month  no_of_rainy_days  total_rainfall  maximum_rainfall_in_a_day  \
# 0 1982-01-01                10           107.1                       36.5
# 1 1982-02-01                 5            27.8                        9.4
# 2 1982-03-01                11           160.8                       61.7
# 3 1982-04-01                14           157.0                       45.1
# 4 1982-05-01                10           102.2                       33.0
#
#    mean_rh  temp_mean_daily_min  temp_mean_daily_max  mean_sunshine_hrs  \
# 0     81.2                 23.3                 29.8                5.6
# 1     79.5                 23.9                 32.3                7.6
# 2     82.3                 24.3                 31.7                5.1
# 3     85.9                 24.3                 31.4                4.7
# 4     83.2                 25.2                 31.7                5.8
#
#    max_temperature  temp_extremes_min
# 0             31.9               21.9
# 1             34.3               22.6
# 2             34.3               22.3
# 3             33.2               22.2
# 4             32.9               23.7

# %% [markdown]
# ---
# Check for nulls:

# %%
#Check for any null values
weather.isna().sum()
# Out:
# month                        0
# no_of_rainy_days             0
# total_rainfall               0
# maximum_rainfall_in_a_day    0
# mean_rh                      0
# temp_mean_daily_min          0
# temp_mean_daily_max          0
# mean_sunshine_hrs            0
# max_temperature              0
# temp_extremes_min            0
# dtype: int64

# %%
#Check for duplicates
duplicates = weather.duplicated()
duplicates.sum()
# Out:
# 0

# %%
#Check datatypes
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 487
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      488 non-null    datetime64[ns]
#  1   no_of_rainy_days           488 non-null    int64
#  2   total_rainfall             488 non-null    float64
#  3   maximum_rainfall_in_a_day  488 non-null    float64
#  4   mean_rh                    488 non-null    float64
#  5   temp_mean_daily_min        488 non-null    float64
#  6   temp_mean_daily_max        488 non-null    float64
#  7   mean_sunshine_hrs          488 non-null    float64
#  8   max_temperature            488 non-null    float64
#  9   temp_extremes_min          488 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 41.9 KB

# %% [markdown]
# ---
# Separate original datetime formatted column into year and month. This is done by temporarily creating a temp dataframe with the year and month columns, and merging it to main weather dataframe:

# %%
#separate year and month into new temporary dataframe
datetime = {'year':weather['month'].dt.year, 'month':weather['month'].dt.month}
datetime = pd.DataFrame(datetime)

# %%
print(datetime.shape)
datetime.head()
# Out:
# (488, 2)
#    year  month
# 0  1982      1
# 1  1982      2
# 2  1982      3
# 3  1982      4
# 4  1982      5

# %%
#drop 'month' from main weather df 
weather.drop(columns = ['month'], axis=1, inplace=True)

#merge datetime df to main weather df
weather = pd.concat(objs = [datetime, weather], axis=1)

# %%
weather.head()
# Out:
#    year  month  no_of_rainy_days  total_rainfall  maximum_rainfall_in_a_day  \
# 0  1982      1                10           107.1                       36.5
# 1  1982      2                 5            27.8                        9.4
# 2  1982      3                11           160.8                       61.7
# 3  1982      4                14           157.0                       45.1
# 4  1982      5                10           102.2                       33.0
#
#    mean_rh  temp_mean_daily_min  temp_mean_daily_max  mean_sunshine_hrs  \
# 0     81.2                 23.3                 29.8                5.6
# 1     79.5                 23.9                 32.3                7.6
# 2     82.3                 24.3                 31.7                5.1
# 3     85.9                 24.3                 31.4                4.7
# 4     83.2                 25.2                 31.7                5.8
#
#    max_temperature  temp_extremes_min
# 0             31.9               21.9
# 1             34.3               22.6
# 2             34.3               22.3
# 3             33.2               22.2
# 4             32.9               23.7

# %% [markdown]
# ---
# Rename column headers to be of snake case and reduced text:

# %%
#rename column headers
weather.rename(columns={
    'no_of_rainy_days': 'rainy_days',
    'maximum_rainfall_in_a_day': 'max_daily_rainfall',
    'temp_mean_daily_min':'min_daily_temp',
     'temp_mean_daily_max':'max_daily_temp',
    'max_temperature':'extr_max_temp',
    'temp_extremes_min':'extr_min_temp',
}, inplace=True)

# %%
weather.head()
# Out:
#    year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 0  1982      1          10           107.1                36.5     81.2
# 1  1982      2           5            27.8                 9.4     79.5
# 2  1982      3          11           160.8                61.7     82.3
# 3  1982      4          14           157.0                45.1     85.9
# 4  1982      5          10           102.2                33.0     83.2
#
#    min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 0            23.3            29.8                5.6           31.9
# 1            23.9            32.3                7.6           34.3
# 2            24.3            31.7                5.1           34.3
# 3            24.3            31.4                4.7           33.2
# 4            25.2            31.7                5.8           32.9
#
#    extr_min_temp
# 0           21.9
# 1           22.6
# 2           22.3
# 3           22.2
# 4           23.7

# %% [markdown]
# ---
# Dataframe clean up complete, we can now export to csv file:

# %%
#export weather df to csv file
import os # to work with files/directories
if not os.path.exists('..\data\output'): 
    os.makedirs('..\data\output') 
weather.to_csv('..\data\output\weather.csv')

# %% [markdown]
# ### 2.2.2 Air Quality Data Import
# This section covers the import and data cleaning of 7 csv files on different air pollutants, and 1 csv file on PSI.
#
# The 7 air pollutants were merged into a single dataframe since they were capturing pollutant amounts against time, in a similar format and time granularity. Note: lead_mean was later dropped towards the end stage, as it was found to be a constant value and amounts were close to negligable. Also, additional research showed lead was not part of the pollutants considered for air quality (PSI) measurements.
#
# The final psi csv was left as a single dataframe.

# %% [markdown]
# ---
# Import air quality related data:

# %%
# Bring in air quality pollutants data
ozone_max_mean = pd.read_csv(r'..\data\air-pollutant-ozone.csv')
pm_mean = pd.read_csv(r'..\data\air-pollutant-particulate-matter-pm2-5.csv')
lead_mean = pd.read_csv(r'..\data\AirPolluantLead.csv')
co_mean = pd.read_csv(r'..\data\AirPollutantCarbonMonoxide2ndMaximum8HourMean.csv')
no2_mean = pd.read_csv(r'..\data\AirPollutantNitrogenDioxide.csv')
pm10_mean = pd.read_csv(r'..\data\AirPollutantParticulateMatterPM10.csv')
so2_mean = pd.read_csv(r'..\data\AirPollutantSulphurDioxide.csv')

#bring in PSI data
psi = pd.read_csv(r'..\data\historical-24-hr-psi.csv')

# %% [markdown]
# ---
# Write a function to do the following for each set of air pollutants data:
# * print shape of dataframe
# * convert month to datetime datatype
# * print info
# * print head to check

# %%
def df_inspectn(df):
    df['month'] = pd.to_datetime(df['year'], format='%Y')
    shape = df.shape
    info = df.info()
    head = df.head()
    
    print(shape)
    print(info)
    return df.head()

# %% [markdown]
# ---
# Use the above function to inspect all dataframes:

# %%
#Inspect the ozone_max_mean data
df_inspectn(ozone_max_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      22 non-null     int64
#  1   ozone_maximum_8hour_mean  22 non-null     int64
#  2   month                     22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 656.0 bytes
# (22, 3)
# None
#    year  ozone_maximum_8hour_mean      month
# 0  2000                       112 2000-01-01
# 1  2001                       133 2001-01-01
# 2  2002                       131 2002-01-01
# 3  2003                       118 2003-01-01
# 4  2004                       146 2004-01-01

# %%
#Inspect the pm_mean data
df_inspectn(pm_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        20 non-null     int64
#  1   pm2.5_mean  20 non-null     int64
#  2   month       20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 608.0 bytes
# (20, 3)
# None
#    year  pm2.5_mean      month
# 0  2002          23 2002-01-01
# 1  2003          19 2003-01-01
# 2  2004          21 2004-01-01
# 3  2005          21 2005-01-01
# 4  2006          23 2006-01-01

# %%
#Inspect the lead_mean data
df_inspectn(lead_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       16 non-null     int64
#  1   lead_mean  16 non-null     object
#  2   month      16 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 512.0+ bytes
# (16, 3)
# None
#    year lead_mean      month
# 0  2006      <0.1 2006-01-01
# 1  2007      <0.1 2007-01-01
# 2  2008      <0.1 2008-01-01
# 3  2009      <0.1 2009-01-01
# 4  2010      <0.1 2010-01-01

# %%
#Inspect the co_mean data
df_inspectn(co_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               22 non-null     int64
#  1   co_max_8hour_mean  22 non-null     float64
#  2   month              22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 656.0 bytes
# (22, 3)
# None
#    year  co_max_8hour_mean      month
# 0  2000                3.7 2000-01-01
# 1  2001                4.2 2001-01-01
# 2  2002                2.7 2002-01-01
# 3  2003                3.2 2003-01-01
# 4  2004                2.8 2004-01-01

# %%
#Inspect the no2_mean data
df_inspectn(no2_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   22 non-null     int64
#  1   nitrogen_dioxide_mean  22 non-null     int64
#  2   month                  22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 656.0 bytes
# (22, 3)
# None
#    year  nitrogen_dioxide_mean      month
# 0  2000                     30 2000-01-01
# 1  2001                     26 2001-01-01
# 2  2002                     27 2002-01-01
# 3  2003                     24 2003-01-01
# 4  2004                     26 2004-01-01

# %%
#Inspect the pm10_mean data
df_inspectn(pm10_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       22 non-null     int64
#  1   pm10_24hour_mean_99th_per  22 non-null     int64
#  2   month                      22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 656.0 bytes
# (22, 3)
# None
#    year  pm10_24hour_mean_99th_per      month
# 0  2000                         64 2000-01-01
# 1  2001                         56 2001-01-01
# 2  2002                         72 2002-01-01
# 3  2003                         52 2003-01-01
# 4  2004                         60 2004-01-01

# %%
#Inspect the so2_mean data
df_inspectn(so2_mean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  22 non-null     int64
#  1   sulphur_dioxide_mean  22 non-null     int64
#  2   month                 22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 656.0 bytes
# (22, 3)
# None
#    year  sulphur_dioxide_mean      month
# 0  2000                    22 2000-01-01
# 1  2001                    22 2001-01-01
# 2  2002                    18 2002-01-01
# 3  2003                    15 2003-01-01
# 4  2004                    14 2004-01-01

# %% [markdown]
# ---
# Merging all the above dataframes into one single dataframe.

# %%
#merge df
air_qlty = pd.merge(left = ozone_max_mean,
                    right = pm_mean,
                    how = 'left',
                    on = 'year')

# %%
#merge df
air_qlty = pd.merge(left = air_qlty,
                    right = lead_mean,
                    how = 'left',
                    on = 'year')

# %%
#merge df
air_qlty = pd.merge(left = air_qlty,
                    right = co_mean,
                    how = 'left',
                    on = 'year')
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\508927282.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'month_x'} in the result is deprecated and will raise a MergeError in a future version.
#   air_qlty = pd.merge(left = air_qlty,

# %%
#merge df
air_qlty = pd.merge(left = air_qlty,
                    right = no2_mean,
                    how = 'left',
                    on = 'year')

# %%
#merge df
air_qlty = pd.merge(left = air_qlty,
                    right = pm10_mean,
                    how = 'left',
                    on = 'year')
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\1532443887.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'month_x'} in the result is deprecated and will raise a MergeError in a future version.
#   air_qlty = pd.merge(left = air_qlty,

# %%
#merge df
air_qlty = pd.merge(left = air_qlty,
                    right = so2_mean,
                    how = 'left',
                    on = 'year')

# %% [markdown]
# ---
# Rename column headers to snake case and reduced text:

# %%
#rename column headers
air_qlty.rename(columns={'ozone_maximum_8hour_mean':'ozone_max_mean',
                        'co_max_8hour_mean':'co_max_mean',
                        'pm10_24hour_mean_99th_per':'pm10_mean',
                        'nitrogen_dioxide_mean':'no2_mean',
                        'sulphur_dioxide_mean':'so2_mean'},
                         inplace=True)

# %%
air_qlty = air_qlty[['year', 'pm2.5_mean', 'pm10_mean', 'ozone_max_mean', 'lead_mean', 'co_max_mean', 'no2_mean', 'so2_mean']]

# %%
air_qlty.head(10)
# Out:
#    year  pm2.5_mean  pm10_mean  ozone_max_mean lead_mean  co_max_mean  \
# 0  2000         NaN         64             112       NaN          3.7
# 1  2001         NaN         56             133       NaN          4.2
# 2  2002        23.0         72             131       NaN          2.7
# 3  2003        19.0         52             118       NaN          3.2
# 4  2004        21.0         60             146       NaN          2.8
# 5  2005        21.0         61             159       NaN          2.4
# 6  2006        23.0        120             136      <0.1          2.6
# 7  2007        19.0         53             206      <0.1          1.7
# 8  2008        16.0         49             183      <0.1          1.6
# 9  2009        19.0         59             105      <0.1          1.9
#
#    no2_mean  so2_mean
# 0        30        22
# 1        26        22
# 2        27        18
# 3        24        15
# 4        26        14
# 5        25        14
# 6        24        11
# 7        22        12
# 8        22        11
# 9        22         9

# %% [markdown]
# ---
# From the original dataset, all lead_mean amounts were shown as '<0.1'. However, this would lead to issues in plotting graphs or comparing correlations, so I decided to round the values up to 0.1.
#
# However, later I decided to drop the column completely, towards the visualisations stage.

# %%
#noticed lead_mean has value '<0.1'
print(air_qlty['lead_mean'].unique())

#replace this to "0.1"
air_qlty = air_qlty.replace({'<0.1': '0.1'})

air_qlty.head(10)
# Out:
# [nan '<0.1']
#    year  pm2.5_mean  pm10_mean  ozone_max_mean lead_mean  co_max_mean  \
# 0  2000         NaN         64             112       NaN          3.7
# 1  2001         NaN         56             133       NaN          4.2
# 2  2002        23.0         72             131       NaN          2.7
# 3  2003        19.0         52             118       NaN          3.2
# 4  2004        21.0         60             146       NaN          2.8
# 5  2005        21.0         61             159       NaN          2.4
# 6  2006        23.0        120             136       0.1          2.6
# 7  2007        19.0         53             206       0.1          1.7
# 8  2008        16.0         49             183       0.1          1.6
# 9  2009        19.0         59             105       0.1          1.9
#
#    no2_mean  so2_mean
# 0        30        22
# 1        26        22
# 2        27        18
# 3        24        15
# 4        26        14
# 5        25        14
# 6        24        11
# 7        22        12
# 8        22        11
# 9        22         9

# %%
#standardize all values to float dtype
air_qlty = air_qlty.astype({'pm10_mean':float, 
                'ozone_max_mean':float, 
                'lead_mean':float,
                'no2_mean':float,
                'so2_mean':float})

air_qlty.head()
# Out:
#    year  pm2.5_mean  pm10_mean  ozone_max_mean  lead_mean  co_max_mean  \
# 0  2000         NaN       64.0           112.0        NaN          3.7
# 1  2001         NaN       56.0           133.0        NaN          4.2
# 2  2002        23.0       72.0           131.0        NaN          2.7
# 3  2003        19.0       52.0           118.0        NaN          3.2
# 4  2004        21.0       60.0           146.0        NaN          2.8
#
#    no2_mean  so2_mean
# 0      30.0      22.0
# 1      26.0      22.0
# 2      27.0      18.0
# 3      24.0      15.0
# 4      26.0      14.0

# %% [markdown]
# ---
# Dataframe clean up complete, we can now export to csv file:

# %%
#export air_qlty df to csv file
import os # to work with files/directories
if not os.path.exists('..\data\output'): 
    os.makedirs('..\data\output') 
    air_qlty.to_csv('..\data\output\air_qlty.csv')

# %% [markdown]
# ---
# Clean up of psi dataframe:

# %%
# Check out the first five rows of the psi data
print(psi.shape)
psi.head()
# Out:
# (67968, 6)
#        24-hr_psi  north  south  east  west  central
# 0  1/4/2014 1:00     55     54    54    58       54
# 1  1/4/2014 2:00     55     54    54    59       54
# 2  1/4/2014 3:00     55     55    54    60       55
# 3  1/4/2014 4:00     56     55    55    62       55
# 4  1/4/2014 5:00     57     55    56    63       56

# %%
# convert '24-hr_psi' to date-time Dtype
psi['24-hr_psi'] = pd.to_datetime(psi['24-hr_psi'], format="%d/%m/%Y %H:%M", errors='coerce')
print(psi.info())

# print head again to check
psi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67968 entries, 0 to 67967
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   24-hr_psi  67967 non-null  datetime64[ns]
#  1   north      67968 non-null  int64
#  2   south      67968 non-null  int64
#  3   east       67968 non-null  int64
#  4   west       67968 non-null  int64
#  5   central    67968 non-null  int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 3.1 MB
# None
#             24-hr_psi  north  south  east  west  central
# 0 2014-04-01 01:00:00     55     54    54    58       54
# 1 2014-04-01 02:00:00     55     54    54    59       54
# 2 2014-04-01 03:00:00     55     55    54    60       55
# 3 2014-04-01 04:00:00     56     55    55    62       55
# 4 2014-04-01 05:00:00     57     55    56    63       56

# %% [markdown]
# ---
# Noticed there is a single row of null value in the 24-hr_psi column. Upon checking back with the original csv file, i found out the value got converted to Nan because it was of a different format from the other cells. It was formatted as "2016-04-04 010:00:00", while other cells were formatted as "3/4/2016 23:00".
#
#
# Find the row with the null and reimport + convert it to correct datetime datatype:

# %%
#find the row with null value
psi.loc[psi['24-hr_psi'].isna()]
# Out:
#       24-hr_psi  north  south  east  west  central
# 17615       NaT     55     53    52    55       53

# %%
#Add in missing 24-hr_psi value which became NaT due to wrong formatting
psi['24-hr_psi'][17615] = "4/4/2016 0:00"
psi['24-hr_psi'] = pd.to_datetime(psi['24-hr_psi'], format="%d/%m/%Y %H:%M", errors='coerce')
psi.iloc[17615]
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\1072104075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   psi['24-hr_psi'][17615] = "4/4/2016 0:00"
# 24-hr_psi    2016-04-04 00:00:00
# north                         55
# south                         53
# east                          52
# west                          55
# central                       53
# Name: 17615, dtype: object

# %%
#split 24-hr_psi column to separate date month year columns
psi['year'] = psi['24-hr_psi'].dt.year
psi['month'] = psi['24-hr_psi'].dt.month
psi['date'] = psi['24-hr_psi'].dt.date
psi['time'] = psi['24-hr_psi'].dt.time

print(psi.info())
psi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67968 entries, 0 to 67967
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   24-hr_psi  67968 non-null  datetime64[ns]
#  1   north      67968 non-null  int64
#  2   south      67968 non-null  int64
#  3   east       67968 non-null  int64
#  4   west       67968 non-null  int64
#  5   central    67968 non-null  int64
#  6   year       67968 non-null  int64
#  7   month      67968 non-null  int64
#  8   date       67968 non-null  object
#  9   time       67968 non-null  object
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 5.2+ MB
# None
#             24-hr_psi  north  south  east  west  central  year  month  \
# 0 2014-04-01 01:00:00     55     54    54    58       54  2014      4
# 1 2014-04-01 02:00:00     55     54    54    59       54  2014      4
# 2 2014-04-01 03:00:00     55     55    54    60       55  2014      4
# 3 2014-04-01 04:00:00     56     55    55    62       55  2014      4
# 4 2014-04-01 05:00:00     57     55    56    63       56  2014      4
#
#          date      time
# 0  2014-04-01  01:00:00
# 1  2014-04-01  02:00:00
# 2  2014-04-01  03:00:00
# 3  2014-04-01  04:00:00
# 4  2014-04-01  05:00:00

# %%
psi.columns
# Out:
# Index(['24-hr_psi', 'north', 'south', 'east', 'west', 'central', 'year',
#        'month', 'date', 'time'],
#       dtype='object')

# %% [markdown]
# ---
# Reorder columns to make dataframe more readable, drop columns not required:

# %%
#reorder the columns
psi = psi[['year', 'month', 'date', 'time', 'north', 'south', 'east', 'west', 'central']]
psi.head()
# Out:
#    year  month        date      time  north  south  east  west  central
# 0  2014      4  2014-04-01  01:00:00     55     54    54    58       54
# 1  2014      4  2014-04-01  02:00:00     55     54    54    59       54
# 2  2014      4  2014-04-01  03:00:00     55     55    54    60       55
# 3  2014      4  2014-04-01  04:00:00     56     55    55    62       55
# 4  2014      4  2014-04-01  05:00:00     57     55    56    63       56

# %% [markdown]
# ---
# I decided to omit the rows after 2020, since most data will be analysed from 2000 - 2020.

# %%
#omit rows after year 2020
#dropping these rows cos none of my other data are analysed past 2020
psi = psi.loc[psi['year']<=2020, :]
psi.tail()
# Out:
#        year  month        date      time  north  south  east  west  central
# 59202  2020     12  2020-12-31  19:00:00     52     55    55    33       48
# 59203  2020     12  2020-12-31  20:00:00     52     55    55    31       47
# 59204  2020     12  2020-12-31  21:00:00     52     55    55    30       48
# 59205  2020     12  2020-12-31  22:00:00     52     55    55    31       49
# 59206  2020     12  2020-12-31  23:00:00     52     55    55    34       49

# %% [markdown]
# ---
# Export inspected and cleaned dataframe to csv file:

# %%
#export psi df to csv file
import os # to work with files/directories
if not os.path.exists('..\data\output'): 
    os.makedirs('..\data\output') 
    psi.to_csv('..\data\output\psi.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 Data Dictionary
#
# <details>
# <summary>More about Data Dictionary</summary>
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
# </details>
# <br>
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**date**|*datetime*|all datasets|1982, January to 2023, May|
# |**year**|*datetime*|all datasets|1982 to 2023|
# |**month**|*datetime*|all datasets|Jan - Dec, represented by 01 - 12 respectively|
# |**rainy_days**|*int*|rainfall-monthly-number-of-rain-days|The number of rain days (day with rainfall amount of 0.2mm or more) in a month recorded|
# |**total_rainfall**|*float*|rainfall-monthly-total|The total monthly rainfall in mm|
# |**max_daily_rainfall**|*float*|rainfall-monthly-highest-daily-total|The highest daily total rainfall for the month|
# |**mean_rh**|*float*|relative-humidity-monthly-mean|The monthly mean relative humidity recorded|
# |**min_daily_temp**|*float*|SurfaceAirTemperatureMonthlyMeanDailyMaximum|The monthly mean daily minimum temperature recorded|
# |**max_daily_temp**|*float*|surface-air-temperature-monthly-mean-daily-minimum|The monthly mean daily maximum temperature recorded|
# |**extr_max_temp**|*float*|SurfaceAirTemperatureMonthlyAbsoluteExtremeMaximum|The monthly extreme maximum air temperature recorded|
# |**extr_min_temp**|*float*|SurfaceAirTemperatureMonthlyAbsoluteExtremeMinimum|The absolute extreme minimum air temperature recorded|
# |**mean_sunshine_hrs**|*float*|sunshine-duration-monthly-mean-daily-duration|The monthly mean sunshine hours in a day recorded|
# |**ozone_max_mean**|*float*|air-pollutant-ozone|Annual daily maximum 8-hr means for ozone (µg/m3)|
# |**pm2.5_mean**|*float*|air-pollutant-particulate-matter-pm2-5|Annual means for PM2.5 (µg/m3)|
# |**pm10_mean**|*float*|AirPollutantParticulateMatterPM10|Annual 24-hr means (99th percentile) for PM10 (µg/m3)|
# |**co_max_mean**|*float*|AirPollutantCarbonMonoxide2ndMaximum8HourMean|Annual maximum 8-hr means for carbon monoxide (mg/m3)|
# |**no2_mean**|*float*|AirPollutantNitrogenDioxide|Annual means for nitrogen dioxide (µg/m3)|
# |**so2_mean**|*float*|AirPollutantSulphurDioxide|Annual means for sulphur dioxide (µg/m3)|
# |**psi**|*float*|historical-24-hr-psi|Historical regional 24-hr PSI|

# %% [markdown]
# ## 2.4 Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 2000, 2005, 2010, 2015 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis (2000-2020)?
#         - Which month have the highest and lowest number of rainy days in 2000, 2005, 2010, 2015 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis (2000-2020)?
#         - Are there any outliers months in the dataset?
#
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.<br>
#
#     - **Other areas I would like to explore are:**
#         - How are the various weather conditions (Mean relative humidity, min daily temperature, sunshine duration, etc) associated with rainfall in Singapore?
#         - How does rainfall impact the Pollutant Standards Index (PSI) in Singapore? Is there a correlation between rainfall and improvements or deteriorations in air quality? Are certain pollutants more responsive to rainfall?
#         - How do the various air pollutants (that contribute to PSI) relate to each other?
#         - How do Singapore's air quality pollutants measure in relation to Singapore's air quality targets?
#         - Are there time lags or temporal relationships between rainfall events and subsequent changes in the PSI?

# %% [markdown]
# ---

# %%
# Show summary statistics
weather.describe()
# Out:
#               year       month  rainy_days  total_rainfall  \
# count   488.000000  488.000000  488.000000      488.000000
# mean   2001.836066    6.467213   14.061475      177.163730
# std      11.752660    3.449095    4.947394      113.916029
# min    1982.000000    1.000000    1.000000        0.200000
# 25%    1992.000000    3.000000   11.000000       93.850000
# 50%    2002.000000    6.000000   14.000000      159.450000
# 75%    2012.000000    9.000000   18.000000      238.075000
# max    2022.000000   12.000000   27.000000      765.900000
#
#        max_daily_rainfall     mean_rh  min_daily_temp  max_daily_temp  \
# count          488.000000  488.000000      488.000000      488.000000
# mean            52.332172   82.247541       24.919467       31.528893
# std             35.746423    3.413940        0.734994        0.868219
# min              0.200000   72.000000       22.900000       28.800000
# 25%             30.675000   80.000000       24.400000       31.000000
# 50%             43.900000   82.650000       24.900000       31.500000
# 75%             63.050000   84.700000       25.400000       32.100000
# max            216.200000   90.700000       27.100000       34.400000
#
#        mean_sunshine_hrs  extr_max_temp  extr_min_temp
# count         488.000000     488.000000     488.000000
# mean            5.688320      33.391189      22.651434
# std             1.205705       0.814590       0.745113
# min             2.700000      31.300000      20.200000
# 25%             4.800000      32.800000      22.200000
# 50%             5.700000      33.300000      22.600000
# 75%             6.500000      33.925000      23.100000
# max             9.300000      36.000000      25.400000

# %%
weather.head()
# Out:
#    year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 0  1982      1          10           107.1                36.5     81.2
# 1  1982      2           5            27.8                 9.4     79.5
# 2  1982      3          11           160.8                61.7     82.3
# 3  1982      4          14           157.0                45.1     85.9
# 4  1982      5          10           102.2                33.0     83.2
#
#    min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 0            23.3            29.8                5.6           31.9
# 1            23.9            32.3                7.6           34.3
# 2            24.3            31.7                5.1           34.3
# 3            24.3            31.4                4.7           33.2
# 4            25.2            31.7                5.8           32.9
#
#    extr_min_temp
# 0           21.9
# 1           22.6
# 2           22.3
# 3           22.2
# 4           23.7

# %%
#Use a dictionary comprehension to apply the std dev function to each numeric column in the dataframe
sd = {columns: std_dev(values) for columns, values in weather.items()}
sd
# Out:
# {'year': 11.740612333388459,
#  'month': 3.4455588574029625,
#  'rainy_days': 4.9423221913224085,
#  'total_rainfall': 113.79925170470057,
#  'max_daily_rainfall': 35.70977918873312,
#  'mean_rh': 3.4104399291902836,
#  'min_daily_temp': 0.7342402416999341,
#  'max_daily_temp': 0.867328906049184,
#  'mean_sunshine_hrs': 1.2044686452879794,
#  'extr_max_temp': 0.8137548451868262,
#  'extr_min_temp': 0.7443489232010556}

# %% [markdown]
# ### 2.4.1 Analysing Total Rainfall and No of Rainy Days per month
# *Compulsory Questions*

# %% [markdown]
# #### Compulsory question 1
# Which months have the highest and lowest total rainfall in 2000, 2005, 2010, 2015, 2020?

# %%
selected_years = [2000, 2005, 2010, 2015, 2020]

#Filter the DataFrame for the selected years
filtered_weather = weather[weather['year'].isin(selected_years)]
filtered_weather.head()
# Out:
#      year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 216  2000      1          14           275.2               127.6     86.9
# 217  2000      2          18           237.8                39.9     86.5
# 218  2000      3          15           238.3                37.9     85.8
# 219  2000      4          20           311.6                87.4     85.6
# 220  2000      5          10            96.8                36.7     82.4
#
#      min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 216            23.9            29.8                4.0           31.8
# 217            23.8            31.0                5.8           32.4
# 218            24.3            31.9                5.8           34.0
# 219            24.6            31.9                5.3           33.4
# 220            25.7            32.7                6.8           34.2
#
#      extr_min_temp
# 216           22.8
# 217           21.7
# 218           20.2
# 219           22.6
# 220           22.6

# %%
#Extract 'year', 'month', 'total rainfall' into new df
rainf_by_month = filtered_weather[['year', 'month', 'total_rainfall']]
rainf_by_month.reset_index(drop=True, inplace=True)
rainf_by_month.head()
# Out:
#    year  month  total_rainfall
# 0  2000      1           275.2
# 1  2000      2           237.8
# 2  2000      3           238.3
# 3  2000      4           311.6
# 4  2000      5            96.8

# %% [markdown]
# ---
# Use the .loc function to search for months with the highest total rainfall for each year:

# %%
#Find the months with the highest rainfall for each year
high_rainf = rainf_by_month.loc[rainf_by_month.groupby('year')['total_rainfall'].idxmax()]
high_rainf.head()
# Out:
#     year  month  total_rainfall
# 10  2000     11           385.7
# 22  2005     11           362.9
# 30  2010      7           298.5
# 47  2015     12           302.3
# 52  2020      5           255.6

# %% [markdown]
# ---
# Use the .loc function to search for months with the lowest total rainfall for each year:

# %%
#Find the months with the lowest total rainfall for each year
low_rainf = rainf_by_month.loc[rainf_by_month.groupby('year')['total_rainfall'].idxmin()]
low_rainf.head()
# Out:
#     year  month  total_rainfall
# 8   2000      9            81.1
# 13  2005      2             8.4
# 25  2010      2             6.3
# 37  2015      2            18.8
# 49  2020      2            65.0

# %% [markdown]
# The 2 dataframes above show us that the highest rainfall largely occur towards the end of the year (in the months of November to December), while lowest total rainfall occur largely in February.
#
# This proposes that total rainfall is a cyclical / seasonal factor.

# %% [markdown]
# ---
# #### Compulsory question 2
# Which year have the highest and lowest total rainfall in the date range of analysis (2000-2020)?

# %%
#Extract 'year', 'month', 'total rainfall' into new df
total_rainf = weather.loc[(weather['year'] >= 2000) & (weather['year'] <= 2020), ['year', 'month', 'total_rainfall']]
total_rainf.head()
# Out:
#      year  month  total_rainfall
# 216  2000      1           275.2
# 217  2000      2           237.8
# 218  2000      3           238.3
# 219  2000      4           311.6
# 220  2000      5            96.8

# %%
#Year with highest total rainfall
high_total_rainf = total_rainf['total_rainfall'].max()
highest_rainfall_row = total_rainf[total_rainf['total_rainfall'] == high_total_rainf]
high_rainf_year = total_rainf['year'].loc[total_rainf['total_rainfall'].idxmax()]

print(f"The year with the highest total rainfall is {high_rainf_year}.")
highest_rainfall_row
# Out:
# The year with the highest total rainfall is 2006.
#      year  month  total_rainfall
# 299  2006     12           765.9

# %%
#Year with lowest total rainfall
low_total_rainf = total_rainf['total_rainfall'].min()
lowest_rainfall_row = total_rainf[total_rainf['total_rainfall'] == low_total_rainf]
low_rainf_year = total_rainf['year'].loc[total_rainf['total_rainfall'].idxmin()]

print(f"The year with the lowest total rainfall is {low_rainf_year}.")
lowest_rainfall_row
# Out:
# The year with the lowest total rainfall is 2014.
#      year  month  total_rainfall
# 385  2014      2             0.2

# %% [markdown]
# ---
# #### Compulsory question 3
# Which month have the highest and lowest number of rainy days in 2000, 2005, 2010, 2015, 2020?

# %%
#Extract 'year', 'month', 'total rainfall' into new df
sel_rainy_days = filtered_weather[['year', 'month', 'rainy_days']]
sel_rainy_days.reset_index(drop=True, inplace=True)
sel_rainy_days.head()
# Out:
#    year  month  rainy_days
# 0  2000      1          14
# 1  2000      2          18
# 2  2000      3          15
# 3  2000      4          20
# 4  2000      5          10

# %%
#Find the months with the highestnumber of rainy days for each year
high_rainy_days = sel_rainy_days.loc[sel_rainy_days.groupby('year')['rainy_days'].idxmax()]
high_rainy_days.head()
# Out:
#     year  month  rainy_days
# 10  2000     11          21
# 22  2005     11          23
# 34  2010     11          21
# 47  2015     12          19
# 54  2020      7          22

# %%
#Find the months with the lowest number of rainy days for each year
low_rainy_days = sel_rainy_days.loc[sel_rainy_days.groupby('year')['rainy_days'].idxmin()]
low_rainy_days.head()
# Out:
#     year  month  rainy_days
# 4   2000      5          10
# 13  2005      2           3
# 25  2010      2           4
# 38  2015      3           5
# 48  2020      1           6

# %% [markdown]
# This reinforces the earlier trend that we identified from question 1.
# Rainfall is a cyclical / seasonal factor - the hot season with lesser rainy days takes place in the earlier half of the year, while the months taking place towards the end of year see more rainy days.

# %% [markdown]
# ---
# #### Compulsory question 4
# Which year have the highest and lowest number of rainy days in the date range of analysis?

# %%
#Extract 'year', 'month', 'rainy_days' into new df
rainy_days = weather.loc[(weather['year'] >= 2000) & (weather['year'] <= 2020), ['year', 'month', 'rainy_days']]

#Year with highest number of rainy days
high_rainy_d = rainy_days['rainy_days'].max()
high_rainy_d_row = rainy_days[rainy_days['rainy_days'] == high_rainy_d]
high_rainf_year = rainy_days['year'].loc[rainy_days['rainy_days'].idxmax()]

print(f"The year with the highest number of rainy days is {high_rainf_year}.")
high_rainy_d_row
# Out:
# The year with the highest number of rainy days is 2018.
#      year  month  rainy_days
# 442  2018     11          27

# %%
#Year with lowest number of rainy days
low_rainy_d = rainy_days['rainy_days'].min()
low_rainy_d_row = rainy_days[rainy_days['rainy_days'] == low_rainy_d]
low_rainf_year = rainy_days['year'].loc[rainy_days['rainy_days'].idxmin()]

print(f"The year with the lowest number of rainy days is {low_rainf_year}.")
low_rainy_d_row
# Out:
# The year with the lowest number of rainy days is 2014.
#      year  month  rainy_days
# 385  2014      2           1

# %% [markdown]
# ---
# #### Compulsory question 5
# Are there any outliers months in the dataset?

# %%
#use a histogram to check for outliers
plt.hist(total_rainf['total_rainfall'])
plt.title('Total Rainfall per Month');

# notation indicating a possible outlier
plt.annotate('Possible outlier', xy=(700, 0.03), xytext=(600, 8), fontsize=7,
            arrowprops=dict(arrowstyle='->', ec='grey', lw=2), bbox=dict(boxstyle="round", fc="0.8"));

# %% [markdown]
# From the histogram, we can identify an outlier (isolated bar) for the variable of Total Rainfall per Month.

# %%
#use a histogram to check for outliers
plt.hist(rainy_days['rainy_days'])
plt.title('Number of Rainy Days per Month');

# %% [markdown]
# From the histogram, there are no outliers for number of rainy days per month.

# %%
weather.columns
# Out:
# Index(['year', 'month', 'rainy_days', 'total_rainfall', 'max_daily_rainfall',
#        'mean_rh', 'min_daily_temp', 'max_daily_temp', 'mean_sunshine_hrs',
#        'extr_max_temp', 'extr_min_temp'],
#       dtype='object')

# %% [markdown]
# ---
# ### 2.4.2 Correlation between the various weather conditions
# Using the corr function to create a dataframe on correlation:

# %%
#How are the various weather conditions (Mean relative humidity, min daily temperature, sunshine duration, etc) associated with rainfall in Singapore?
#find correlation between various weather conditions using .corr()
weather_cond = weather.loc[:,['year', 'rainy_days', 'total_rainfall', 'max_daily_rainfall', 'mean_rh',
       'min_daily_temp', 'max_daily_temp', 'mean_sunshine_hrs', 'extr_max_temp',
       'extr_min_temp']]
weather_cond = weather_cond.set_index('year')
weather_cond.corr()
# Out:
#                     rainy_days  total_rainfall  max_daily_rainfall   mean_rh  \
# rainy_days            1.000000        0.684252            0.396088  0.582346
# total_rainfall        0.684252        1.000000            0.810002  0.592447
# max_daily_rainfall    0.396088        0.810002            1.000000  0.438402
# mean_rh               0.582346        0.592447            0.438402  1.000000
# min_daily_temp       -0.320566       -0.463821           -0.364366 -0.638091
# max_daily_temp       -0.472289       -0.572425           -0.440159 -0.567153
# mean_sunshine_hrs    -0.679018       -0.575614           -0.387892 -0.594081
# extr_max_temp        -0.288046       -0.389725           -0.299722 -0.439883
# extr_min_temp        -0.234252       -0.295437           -0.256298 -0.275903
#
#                     min_daily_temp  max_daily_temp  mean_sunshine_hrs  \
# rainy_days               -0.320566       -0.472289          -0.679018
# total_rainfall           -0.463821       -0.572425          -0.575614
# max_daily_rainfall       -0.364366       -0.440159          -0.387892
# mean_rh                  -0.638091       -0.567153          -0.594081
# min_daily_temp            1.000000        0.681289           0.420534
# max_daily_temp            0.681289        1.000000           0.612172
# mean_sunshine_hrs         0.420534        0.612172           1.000000
# extr_max_temp             0.535414        0.840161           0.380067
# extr_min_temp             0.451549        0.429629           0.264387
#
#                     extr_max_temp  extr_min_temp
# rainy_days              -0.288046      -0.234252
# total_rainfall          -0.389725      -0.295437
# max_daily_rainfall      -0.299722      -0.256298
# mean_rh                 -0.439883      -0.275903
# min_daily_temp           0.535414       0.451549
# max_daily_temp           0.840161       0.429629
# mean_sunshine_hrs        0.380067       0.264387
# extr_max_temp            1.000000       0.356748
# extr_min_temp            0.356748       1.000000

# %% [markdown]
# We can tell that temperature and sunshine hours are generally inversely correlated to the other weather conditions such as relative humidity and rainfall. We shall plot this in a heatmap later on to be able to identify correlation more easily.

# %% [markdown]
# ---
# ### 2.4.3 Analysing mean temperature variations (differences between extreme min and extreme max temperatures)

# %% [markdown]
# The rationale behind this segment: To see if there is any clear trend to show temperatures becoming increasingly erratic within the month, i.e. having larger differences within a month. Larger differences means that temperature fluctuates more within a month, which is unusual due to our general stable weather conditions.

# %%
#What's the diff btwn the monthly extreme min and max temperature? 
# comparing present difference between min and max would confirm the trend of weather becoming increasingly extreme and erratic

#add new column showing diff in extreme temps
weather['extr_temp_diff'] = weather['extr_max_temp'] - weather['extr_min_temp']

weather.head()
# Out:
#    year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 0  1982      1          10           107.1                36.5     81.2
# 1  1982      2           5            27.8                 9.4     79.5
# 2  1982      3          11           160.8                61.7     82.3
# 3  1982      4          14           157.0                45.1     85.9
# 4  1982      5          10           102.2                33.0     83.2
#
#    min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 0            23.3            29.8                5.6           31.9
# 1            23.9            32.3                7.6           34.3
# 2            24.3            31.7                5.1           34.3
# 3            24.3            31.4                4.7           33.2
# 4            25.2            31.7                5.8           32.9
#
#    extr_min_temp  extr_temp_diff
# 0           21.9            10.0
# 1           22.6            11.7
# 2           22.3            12.0
# 3           22.2            11.0
# 4           23.7             9.2

# %%
#Find the mean extreme_temp_diff per year from 2000-2020
df_extr_temp_diff = weather[(weather['year'] >= 2000) & (weather['year'] <= 2020)].groupby('year')[['extr_temp_diff']].mean()
df_extr_temp_diff
# Out:
#       extr_temp_diff
# year
# 2000       10.975000
# 2001       10.691667
# 2002       10.625000
# 2003       10.375000
# 2004       10.733333
# 2005       11.316667
# 2006       10.266667
# 2007       10.566667
# 2008       10.616667
# 2009       10.650000
# 2010       11.358333
# 2011       10.600000
# 2012       10.325000
# 2013       11.483333
# 2014       10.833333
# 2015       10.391667
# 2016       10.600000
# 2017       10.233333
# 2018       11.100000
# 2019       10.916667
# 2020       10.200000

# %% [markdown]
# ---
# Do a quick plot of the extreme min and max temp differences:

# %%
# Establish the size of the figure.
plt.figure(figsize = (8, 6))

# Create line plot of GOOG volume over time.
plt.plot(df_extr_temp_diff.index,
         df_extr_temp_diff['extr_temp_diff'],
         label = 'Temp Diff')

# legend placement on plot
plt.title('Extreme Temperature Differences')
plt.legend(loc = 'upper right', fontsize = 'small');

# %%
#From the above, find the year with the max and min difference in extreme max, min temperature
max_year = int(df_extr_temp_diff.idxmax())
min_year = int(df_extr_temp_diff.idxmin())

print(f"The year {max_year} has the maximum difference of {float(df_extr_temp_diff.max()):.2f} degcelc, between the mean monthly absolute extreme max and min temperatures.")
print(f"The year {min_year} has the minimum difference of {float(df_extr_temp_diff.min()):.2f} degcelc, between the mean monthly absolute extreme max and min temperatures.")
# Out:
# The year 2013 has the maximum difference of 11.48 degcelc, between the mean monthly absolute extreme max and min temperatures.
# The year 2020 has the minimum difference of 10.20 degcelc, between the mean monthly absolute extreme max and min temperatures.

# %% [markdown]
# From the graph above, we can see that there is a falling trend with regards to the extreme temperature differences, however, with major fluctuations.

# %% [markdown]
# ---
# ### 2.4.3 Analysing mean temperature variations (differences between mean daily min and max temperatures)
# This study is similar to the above, however, this time studying mean daily temperatures to see if results are different.

# %%
#What's the diff btwn the mean daily min and max temperature? 
#add new column showing diff in extreme temps
weather['daily_temp_diff'] = weather['max_daily_temp'] - weather['min_daily_temp']

weather.head()
# Out:
#    year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 0  1982      1          10           107.1                36.5     81.2
# 1  1982      2           5            27.8                 9.4     79.5
# 2  1982      3          11           160.8                61.7     82.3
# 3  1982      4          14           157.0                45.1     85.9
# 4  1982      5          10           102.2                33.0     83.2
#
#    min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 0            23.3            29.8                5.6           31.9
# 1            23.9            32.3                7.6           34.3
# 2            24.3            31.7                5.1           34.3
# 3            24.3            31.4                4.7           33.2
# 4            25.2            31.7                5.8           32.9
#
#    extr_min_temp  extr_temp_diff  daily_temp_diff
# 0           21.9            10.0              6.5
# 1           22.6            11.7              8.4
# 2           22.3            12.0              7.4
# 3           22.2            11.0              7.1
# 4           23.7             9.2              6.5

# %%
#Find the mean extreme_temp_diff per year from 2000-2020
df_daily_temp_diff = weather[(weather['year'] >= 2000) & (weather['year'] <= 2020)].groupby('year')[['daily_temp_diff']].mean()
df_daily_temp_diff
# Out:
#       daily_temp_diff
# year
# 2000         6.716667
# 2001         6.491667
# 2002         6.791667
# 2003         6.375000
# 2004         6.616667
# 2005         6.758333
# 2006         6.458333
# 2007         6.350000
# 2008         6.350000
# 2009         6.708333
# 2010         7.066667
# 2011         6.466667
# 2012         6.216667
# 2013         6.316667
# 2014         6.325000
# 2015         6.108333
# 2016         6.208333
# 2017         5.900000
# 2018         6.225000
# 2019         6.383333
# 2020         6.216667

# %%
# Establish the size of the figure.
plt.figure(figsize = (8, 6))

# Create line plot
plt.plot(df_daily_temp_diff.index,
         df_daily_temp_diff['daily_temp_diff'],
         label = 'Temp Diff')

# legend placement on plot
plt.title('Daily Temperature Differences')
plt.legend(loc = 'upper right', fontsize = 'small');

# %%
#From the above, find the year with the max and min difference in min and max daily temperature
max_year = int(df_daily_temp_diff.idxmax())
min_year = int(df_daily_temp_diff.idxmin())

print(f"The year {max_year} has the maximum difference of {float(df_daily_temp_diff.max()):.2f} degcelc, between the mean min and max daily temperature.")
print(f"The year {min_year} has the minimum difference of {float(df_daily_temp_diff.min()):.2f} degcelc, between the mean min and max daily temperature.")
# Out:
# The year 2010 has the maximum difference of 7.07 degcelc, between the mean min and max daily temperature.
# The year 2017 has the minimum difference of 5.90 degcelc, between the mean min and max daily temperature.

# %% [markdown]
# The downward trend of temperature difference is seen even more clearly here. The results of this graph plotting mean daily temperature differences and the graph plotting extreme temp differences per month were not what I expected, considering the news reports of erratic temperatures. However, the erratic temperatures could be accounting for a different duration - quarterly mean, etc. Considering the graphs only plotted temperatures from 2000-2020, this phenomenon may not have been captured in the data yet.

# %% [markdown]
# ---
# ### 2.4.4 Analysing warmer/cooler temperatures that went above/below the 20year mean maximum/minimum daily temperature respectively, and reduced total rainfall that fell below the 20 year mean.

# %% [markdown]
# **Analysing temperature first:**

# %%
#Count number and percentage of months that temperature went above the 20 year mean min and max daily temperature
#calculate the 20 year mean min daily temperature
mean_min_daily = weather['min_daily_temp'].mean()
mean_min_daily
# Out:
# 24.919467213114757

# %%
#calculate the 20 year mean max daily temperature
mean_max_daily = weather['max_daily_temp'].mean()
mean_max_daily
# Out:
# 31.52889344262295

# %% [markdown]
# ---
# Creating a function to highlight various values in the dataframe:
# * Blue for values that fall below mean minimum temperature
# * Red for values that exceed mean maximum temperature

# %%
#Highlight all max daily temps that exceed mean_max_daily, and highlight all min daily temps that fall below mean_min_daily
df_daily_temp = weather.loc[(weather['year'] >= 2000) & (weather['year'] <= 2020), ['year', 'month', 'min_daily_temp', 'max_daily_temp']]

#Create the function to color values below mean min to blue
#Create the function to color values above mean max to orange
def color_for_temp(value):
    if value >= mean_max_daily and value < 2000:
        return 'color: red'

    elif value >= 2000:
        return 'color: black'

    elif value <= mean_min_daily and value > 12:
        return 'color: blue'
        
    else:
        return 'color: black'
        
#We apply the function to all the element in the data frame by using the applymap function
df_daily_temp.style.applymap(color_for_temp)
# Out:
# <style type="text/css">
# #T_95f46_row0_col0, #T_95f46_row0_col1, #T_95f46_row0_col3, #T_95f46_row1_col0, #T_95f46_row1_col1, #T_95f46_row1_col3, #T_95f46_row2_col0, #T_95f46_row2_col1, #T_95f46_row3_col0, #T_95f46_row3_col1, #T_95f46_row4_col0, #T_95f46_row4_col1, #T_95f46_row4_col2, #T_95f46_row5_col0, #T_95f46_row5_col1, #T_95f46_row5_col3, #T_95f46_row6_col0, #T_95f46_row6_col1, #T_95f46_row6_col2, #T_95f46_row7_col0, #T_95f46_row7_col1, #T_95f46_row7_col3, #T_95f46_row8_col0, #T_95f46_row8_col1, #T_95f46_row8_col2, #T_95f46_row9_col0, #T_95f46_row9_col1, #T_95f46_row10_col0, #T_95f46_row10_col1, #T_95f46_row10_col3, #T_95f46_row11_col0, #T_95f46_row11_col1, #T_95f46_row11_col3, #T_95f46_row12_col0, #T_95f46_row12_col1, #T_95f46_row12_col3, #T_95f46_row13_col0, #T_95f46_row13_col1, #T_95f46_row13_col3, #T_95f46_row14_col0, #T_95f46_row14_col1, #T_95f46_row15_col0, #T_95f46_row15_col1, #T_95f46_row15_col2, #T_95f46_row16_col0, #T_95f46_row16_col1, #T_95f46_row16_col2, #T_95f46_row17_col0, #T_95f46_row17_col1, #T_95f46_row17_col2, #T_95f46_row17_col3, #T_95f46_row18_col0, #T_95f46_row18_col1, #T_95f46_row18_col2, #T_95f46_row19_col0, #T_95f46_row19_col1, #T_95f46_row19_col2, #T_95f46_row19_col3, #T_95f46_row20_col0, #T_95f46_row20_col1, #T_95f46_row20_col2, #T_95f46_row21_col0, #T_95f46_row21_col1, #T_95f46_row21_col3, #T_95f46_row22_col0, #T_95f46_row22_col1, #T_95f46_row22_col3, #T_95f46_row23_col0, #T_95f46_row23_col1, #T_95f46_row23_col3, #T_95f46_row24_col0, #T_95f46_row24_col1, #T_95f46_row24_col3, #T_95f46_row25_col0, #T_95f46_row25_col1, #T_95f46_row25_col3, #T_95f46_row26_col0, #T_95f46_row26_col1, #T_95f46_row26_col2, #T_95f46_row27_col0, #T_95f46_row27_col1, #T_95f46_row27_col2, #T_95f46_row28_col0, #T_95f46_row28_col1, #T_95f46_row28_col2, #T_95f46_row29_col0, #T_95f46_row29_col1, #T_95f46_row29_col2, #T_95f46_row30_col0, #T_95f46_row30_col1, #T_95f46_row30_col2, #T_95f46_row31_col0, #T_95f46_row31_col1, #T_95f46_row31_col2, #T_95f46_row32_col0, #T_95f46_row32_col1, #T_95f46_row32_col2, #T_95f46_row33_col0, #T_95f46_row33_col1, #T_95f46_row33_col2, #T_95f46_row34_col0, #T_95f46_row34_col1, #T_95f46_row35_col0, #T_95f46_row35_col1, #T_95f46_row35_col3, #T_95f46_row36_col0, #T_95f46_row36_col1, #T_95f46_row36_col3, #T_95f46_row37_col0, #T_95f46_row37_col1, #T_95f46_row37_col3, #T_95f46_row38_col0, #T_95f46_row38_col1, #T_95f46_row38_col2, #T_95f46_row39_col0, #T_95f46_row39_col1, #T_95f46_row39_col2, #T_95f46_row40_col0, #T_95f46_row40_col1, #T_95f46_row40_col2, #T_95f46_row41_col0, #T_95f46_row41_col1, #T_95f46_row41_col2, #T_95f46_row42_col0, #T_95f46_row42_col1, #T_95f46_row42_col2, #T_95f46_row42_col3, #T_95f46_row43_col0, #T_95f46_row43_col1, #T_95f46_row43_col2, #T_95f46_row44_col0, #T_95f46_row44_col1, #T_95f46_row44_col3, #T_95f46_row45_col0, #T_95f46_row45_col1, #T_95f46_row45_col3, #T_95f46_row46_col0, #T_95f46_row46_col1, #T_95f46_row46_col3, #T_95f46_row47_col0, #T_95f46_row47_col1, #T_95f46_row47_col3, #T_95f46_row48_col0, #T_95f46_row48_col1, #T_95f46_row48_col3, #T_95f46_row49_col0, #T_95f46_row49_col1, #T_95f46_row50_col0, #T_95f46_row50_col1, #T_95f46_row51_col0, #T_95f46_row51_col1, #T_95f46_row51_col2, #T_95f46_row52_col0, #T_95f46_row52_col1, #T_95f46_row52_col2, #T_95f46_row53_col0, #T_95f46_row53_col1, #T_95f46_row53_col2, #T_95f46_row54_col0, #T_95f46_row54_col1, #T_95f46_row54_col3, #T_95f46_row55_col0, #T_95f46_row55_col1, #T_95f46_row55_col2, #T_95f46_row56_col0, #T_95f46_row56_col1, #T_95f46_row56_col2, #T_95f46_row57_col0, #T_95f46_row57_col1, #T_95f46_row57_col2, #T_95f46_row58_col0, #T_95f46_row58_col1, #T_95f46_row58_col3, #T_95f46_row59_col0, #T_95f46_row59_col1, #T_95f46_row59_col3, #T_95f46_row60_col0, #T_95f46_row60_col1, #T_95f46_row60_col3, #T_95f46_row61_col0, #T_95f46_row61_col1, #T_95f46_row61_col2, #T_95f46_row62_col0, #T_95f46_row62_col1, #T_95f46_row62_col2, #T_95f46_row63_col0, #T_95f46_row63_col1, #T_95f46_row63_col2, #T_95f46_row64_col0, #T_95f46_row64_col1, #T_95f46_row64_col2, #T_95f46_row65_c ...

# %% [markdown]
# ---
# Calculating no of months and percentage of months that min daily temps that fall below mean_min_daily:

# %%
#Calculate no & percentage of months that min daily temps that fall below mean_min_daily
below_min = len(df_daily_temp.loc[(df_daily_temp['min_daily_temp']<= mean_min_daily) & (df_daily_temp['min_daily_temp'] > 12),:])
total = len(df_daily_temp['min_daily_temp'])
print(f"Number of months that min daily temperatures that fall below mean daily minimum temperature: {below_min}")
print(f"Percentage: {(below_min / total)*100:.2f}%")
# Out:
# Number of months that min daily temperatures that fall below mean daily minimum temperature: 103
# Percentage: 40.87%

# %% [markdown]
# Calculating no of months and percentage of months that min daily temps that fall below mean_min_daily:

# %%
#Calculate no & percentage of months that max daily temps exceed mean_max_daily
exceed_max = len(df_daily_temp.loc[(df_daily_temp['max_daily_temp']<= mean_max_daily) & (df_daily_temp['max_daily_temp'] > 12),:])
total = len(df_daily_temp['max_daily_temp'])
print(f"Number of months that max daily temperature exceeds mean daily maximum temperature: {exceed_max}")
print(f"Percentage: {(exceed_max / total)*100:.2f}%")
# Out:
# Number of months that max daily temperature exceeds mean daily maximum temperature: 125
# Percentage: 49.60%

# %% [markdown]
# ---
# **Analysing total rainfall:**

# %%
#Count number and percentage of months that total rainfall went below its 20 year mean 
#calculate the 20 year mean total rainfall
mean_tot_rainf = weather['total_rainfall'].mean()
mean_tot_rainf
# Out:
# 177.1637295081967

# %% [markdown]
# ---
# Creating a function to highlight values that fall below mean minimum rainfall:

# %%
#Highlight all months that total rainfall fall below mean 
df_tot_rainf = weather.loc[(weather['year'] >= 2000) & (weather['year'] <= 2020), ['year', 'month', 'total_rainfall']]

#Create the function to color values below mean min to blue
def color_rainf_under(value):
    if value <= mean_tot_rainf and value > 12:
        return 'color: blue'

    else:
        return 'color: black'
        
#We apply the function to all the element in the data frame by using the applymap function
df_tot_rainf.style.applymap(color_rainf_under)
# Out:
# <style type="text/css">
# #T_0d9e4_row0_col0, #T_0d9e4_row0_col1, #T_0d9e4_row0_col2, #T_0d9e4_row1_col0, #T_0d9e4_row1_col1, #T_0d9e4_row1_col2, #T_0d9e4_row2_col0, #T_0d9e4_row2_col1, #T_0d9e4_row2_col2, #T_0d9e4_row3_col0, #T_0d9e4_row3_col1, #T_0d9e4_row3_col2, #T_0d9e4_row4_col0, #T_0d9e4_row4_col1, #T_0d9e4_row5_col0, #T_0d9e4_row5_col1, #T_0d9e4_row6_col0, #T_0d9e4_row6_col1, #T_0d9e4_row7_col0, #T_0d9e4_row7_col1, #T_0d9e4_row8_col0, #T_0d9e4_row8_col1, #T_0d9e4_row9_col0, #T_0d9e4_row9_col1, #T_0d9e4_row10_col0, #T_0d9e4_row10_col1, #T_0d9e4_row10_col2, #T_0d9e4_row11_col0, #T_0d9e4_row11_col1, #T_0d9e4_row11_col2, #T_0d9e4_row12_col0, #T_0d9e4_row12_col1, #T_0d9e4_row12_col2, #T_0d9e4_row13_col0, #T_0d9e4_row13_col1, #T_0d9e4_row14_col0, #T_0d9e4_row14_col1, #T_0d9e4_row14_col2, #T_0d9e4_row15_col0, #T_0d9e4_row15_col1, #T_0d9e4_row15_col2, #T_0d9e4_row16_col0, #T_0d9e4_row16_col1, #T_0d9e4_row17_col0, #T_0d9e4_row17_col1, #T_0d9e4_row18_col0, #T_0d9e4_row18_col1, #T_0d9e4_row19_col0, #T_0d9e4_row19_col1, #T_0d9e4_row20_col0, #T_0d9e4_row20_col1, #T_0d9e4_row21_col0, #T_0d9e4_row21_col1, #T_0d9e4_row21_col2, #T_0d9e4_row22_col0, #T_0d9e4_row22_col1, #T_0d9e4_row23_col0, #T_0d9e4_row23_col1, #T_0d9e4_row23_col2, #T_0d9e4_row24_col0, #T_0d9e4_row24_col1, #T_0d9e4_row24_col2, #T_0d9e4_row25_col0, #T_0d9e4_row25_col1, #T_0d9e4_row26_col0, #T_0d9e4_row26_col1, #T_0d9e4_row27_col0, #T_0d9e4_row27_col1, #T_0d9e4_row28_col0, #T_0d9e4_row28_col1, #T_0d9e4_row28_col2, #T_0d9e4_row29_col0, #T_0d9e4_row29_col1, #T_0d9e4_row30_col0, #T_0d9e4_row30_col1, #T_0d9e4_row30_col2, #T_0d9e4_row31_col0, #T_0d9e4_row31_col1, #T_0d9e4_row32_col0, #T_0d9e4_row32_col1, #T_0d9e4_row33_col0, #T_0d9e4_row33_col1, #T_0d9e4_row33_col2, #T_0d9e4_row34_col0, #T_0d9e4_row34_col1, #T_0d9e4_row34_col2, #T_0d9e4_row35_col0, #T_0d9e4_row35_col1, #T_0d9e4_row35_col2, #T_0d9e4_row36_col0, #T_0d9e4_row36_col1, #T_0d9e4_row36_col2, #T_0d9e4_row37_col0, #T_0d9e4_row37_col1, #T_0d9e4_row38_col0, #T_0d9e4_row38_col1, #T_0d9e4_row39_col0, #T_0d9e4_row39_col1, #T_0d9e4_row40_col0, #T_0d9e4_row40_col1, #T_0d9e4_row41_col0, #T_0d9e4_row41_col1, #T_0d9e4_row42_col0, #T_0d9e4_row42_col1, #T_0d9e4_row43_col0, #T_0d9e4_row43_col1, #T_0d9e4_row43_col2, #T_0d9e4_row44_col0, #T_0d9e4_row44_col1, #T_0d9e4_row44_col2, #T_0d9e4_row45_col0, #T_0d9e4_row45_col1, #T_0d9e4_row45_col2, #T_0d9e4_row46_col0, #T_0d9e4_row46_col1, #T_0d9e4_row47_col0, #T_0d9e4_row47_col1, #T_0d9e4_row47_col2, #T_0d9e4_row48_col0, #T_0d9e4_row48_col1, #T_0d9e4_row48_col2, #T_0d9e4_row49_col0, #T_0d9e4_row49_col1, #T_0d9e4_row50_col0, #T_0d9e4_row50_col1, #T_0d9e4_row50_col2, #T_0d9e4_row51_col0, #T_0d9e4_row51_col1, #T_0d9e4_row52_col0, #T_0d9e4_row52_col1, #T_0d9e4_row53_col0, #T_0d9e4_row53_col1, #T_0d9e4_row54_col0, #T_0d9e4_row54_col1, #T_0d9e4_row55_col0, #T_0d9e4_row55_col1, #T_0d9e4_row55_col2, #T_0d9e4_row56_col0, #T_0d9e4_row56_col1, #T_0d9e4_row57_col0, #T_0d9e4_row57_col1, #T_0d9e4_row58_col0, #T_0d9e4_row58_col1, #T_0d9e4_row59_col0, #T_0d9e4_row59_col1, #T_0d9e4_row60_col0, #T_0d9e4_row60_col1, #T_0d9e4_row61_col0, #T_0d9e4_row61_col1, #T_0d9e4_row61_col2, #T_0d9e4_row62_col0, #T_0d9e4_row62_col1, #T_0d9e4_row63_col0, #T_0d9e4_row63_col1, #T_0d9e4_row64_col0, #T_0d9e4_row64_col1, #T_0d9e4_row64_col2, #T_0d9e4_row65_col0, #T_0d9e4_row65_col1, #T_0d9e4_row66_col0, #T_0d9e4_row66_col1, #T_0d9e4_row67_col0, #T_0d9e4_row67_col1, #T_0d9e4_row68_col0, #T_0d9e4_row68_col1, #T_0d9e4_row69_col0, #T_0d9e4_row69_col1, #T_0d9e4_row69_col2, #T_0d9e4_row70_col0, #T_0d9e4_row70_col1, #T_0d9e4_row70_col2, #T_0d9e4_row71_col0, #T_0d9e4_row71_col1, #T_0d9e4_row72_col0, #T_0d9e4_row72_col1, #T_0d9e4_row72_col2, #T_0d9e4_row73_col0, #T_0d9e4_row73_col1, #T_0d9e4_row74_col0, #T_0d9e4_row74_col1, #T_0d9e4_row75_col0, #T_0d9e4_row75_col1, #T_0d9e4_row75_col2, #T_0d9e4_row76_col0, #T_0d9e4_row76_col1, #T_0d9e4_row76_col2, #T_0d9e4_row77_col0, #T_0d9e4_row77_col1, #T_0d9e4_row77_col2, #T_0d9e4_row78_col0, #T_0d9e4_row78_col1, #T_0d9e4_row7 ...

# %% [markdown]
# ---
# Calculating no of months and percentage of months that min total rainfall that fall below 20 year mean value:

# %%
#Calculate no & percentage of months that total rainfall fall below 20 year mean value
below_mean_temp = len(df_tot_rainf.loc[(df_tot_rainf['total_rainfall']<= mean_tot_rainf) & (df_tot_rainf['total_rainfall'] > 12),:])
total = len(df_tot_rainf['total_rainfall'])
print(f"Number of months that total rainfall fall below 20 year mean value: {below_mean_temp}")
print(f"Percentage: {(below_mean_temp / total)*100:.2f}%")
# Out:
# Number of months that total rainfall fall below 20 year mean value: 146
# Percentage: 57.94%

# %% [markdown]
# ---
# ### 2.4.5 Analyse if the "less ideal" weather conditions studied above, translate into less healthy PSI Index indicators

# %% [markdown]
# Filter the airquality dataframe to show data from 2000 - 2020:

# %%
#filter air_qlty table to show only 2000-2020
#make year the index in air_qlty df
air_qlty = air_qlty.set_index('year')

#filter to include only 2000-2020
air_qlty = air_qlty.loc[(air_qlty.index >= 2000) & (air_qlty.index <= 2020),:]
air_qlty.head()
# Out:
#       pm2.5_mean  pm10_mean  ozone_max_mean  lead_mean  co_max_mean  no2_mean  \
# year
# 2000         NaN       64.0           112.0        NaN          3.7      30.0
# 2001         NaN       56.0           133.0        NaN          4.2      26.0
# 2002        23.0       72.0           131.0        NaN          2.7      27.0
# 2003        19.0       52.0           118.0        NaN          3.2      24.0
# 2004        21.0       60.0           146.0        NaN          2.8      26.0
#
#       so2_mean
# year
# 2000      22.0
# 2001      22.0
# 2002      18.0
# 2003      15.0
# 2004      14.0

# %%
print(psi.columns)
psi.head()
# Out:
# Index(['year', 'month', 'date', 'time', 'north', 'south', 'east', 'west',
#        'central'],
#       dtype='object')
#    year  month        date      time  north  south  east  west  central
# 0  2014      4  2014-04-01  01:00:00     55     54    54    58       54
# 1  2014      4  2014-04-01  02:00:00     55     54    54    59       54
# 2  2014      4  2014-04-01  03:00:00     55     55    54    60       55
# 3  2014      4  2014-04-01  04:00:00     56     55    55    62       55
# 4  2014      4  2014-04-01  05:00:00     57     55    56    63       56

# %% [markdown]
# Since original data only has PSIs categorized by location, we need to create a column for overall Singapore PSI, which takes the mean of the PSIs from various locations:

# %%
#add a column for overall psi 
psi['overall'] = (psi['north']+psi['south']+psi['east']+psi['west']+psi['central'])/5
psi.head()
# Out:
#    year  month        date      time  north  south  east  west  central  \
# 0  2014      4  2014-04-01  01:00:00     55     54    54    58       54
# 1  2014      4  2014-04-01  02:00:00     55     54    54    59       54
# 2  2014      4  2014-04-01  03:00:00     55     55    54    60       55
# 3  2014      4  2014-04-01  04:00:00     56     55    55    62       55
# 4  2014      4  2014-04-01  05:00:00     57     55    56    63       56
#
#    overall
# 0     55.0
# 1     55.2
# 2     55.8
# 3     56.6
# 4     57.4

# %% [markdown]
# We extract another dataframe, which gives us the mean PSIs when grouped by year:

# %%
#Create a column in air_qlty to show PSI as indicator ranges

#Calculate average PSI (a way of measuring AQI) from PSI df
psi_yearly_mean = psi.groupby('year')[['north', 'south', 'east', 'west',
       'central', 'overall']].mean()

psi_yearly_mean
# Out:
#           north      south       east       west    central    overall
# year
# 2014  56.412638  54.805274  54.801637  57.248674  54.194726  55.492590
# 2015  62.502740  62.880822  62.933333  65.582991  58.274087  62.434795
# 2016  53.841075  51.736339  50.436362  49.148110  50.490323  51.130442
# 2017  52.183333  50.879338  50.023973  46.142922  47.094863  49.264886
# 2018  52.567237  53.880023  51.160388  47.656164  52.549087  51.562580
# 2019  51.573402  54.689726  53.405251  50.224543  52.810160  52.540616
# 2020  44.141052  45.189208  44.736111  38.477573  44.487136  43.406216

# %%
#merge overall PSI to air_qlty dataframe
air_qlty_psi = air_qlty.merge(psi_yearly_mean[['overall']], left_index=True, right_index=True, how='left')

#rename overall to overall_psi
air_qlty_psi.rename(columns={'overall':'overall_psi'},
                         inplace=True)

air_qlty_psi.tail()
# Out:
#       pm2.5_mean  pm10_mean  ozone_max_mean  lead_mean  co_max_mean  no2_mean  \
# year
# 2016        15.0       61.0           115.0        0.1          2.2      26.0
# 2017        14.0       57.0           191.0        0.1          1.7      25.0
# 2018        15.0       59.0           150.0        0.1          2.0      26.0
# 2019        16.0       90.0           125.0        0.1          1.7      23.0
# 2020        11.0       43.0           145.0        0.1          1.2      20.0
#
#       so2_mean  overall_psi
# year
# 2016      13.0    51.130442
# 2017      12.0    49.264886
# 2018       9.0    51.562580
# 2019       8.0    52.540616
# 2020       5.0    43.406216

# %% [markdown]
# ---
# In order to see how the PSI number translates to Singapores indicators, we create a column in air_qlty to show PSI as indicator ranges.
# We then sort psi into ranges - according to Singapore's indicator indexes, by creating a function:

# %%
def psi_range(value):
    if value == "NaN":
        return None
    elif value <= 50:
        return "Good"
    elif value <= 100:
        return "Moderate"
    elif value < 200:
        return "Unhealthy"
    elif value < 300:
        return "Very Unhealthy"
    else:
        return "Hazardous"

# Apply the function to replace values within the range
air_qlty_psi['psi_index'] = air_qlty_psi['overall_psi'].apply(psi_range)

air_qlty_psi.tail()
# Out:
#       pm2.5_mean  pm10_mean  ozone_max_mean  lead_mean  co_max_mean  no2_mean  \
# year
# 2016        15.0       61.0           115.0        0.1          2.2      26.0
# 2017        14.0       57.0           191.0        0.1          1.7      25.0
# 2018        15.0       59.0           150.0        0.1          2.0      26.0
# 2019        16.0       90.0           125.0        0.1          1.7      23.0
# 2020        11.0       43.0           145.0        0.1          1.2      20.0
#
#       so2_mean  overall_psi psi_index
# year
# 2016      13.0    51.130442  Moderate
# 2017      12.0    49.264886      Good
# 2018       9.0    51.562580  Moderate
# 2019       8.0    52.540616  Moderate
# 2020       5.0    43.406216      Good

# %% [markdown]
# ---
# For years where temperature exceeds mean, what is the percentage for each indicator? The rationale behind this study, is to see how the less ideal warmer temperatures translates to PSI index indicators.

# %%
#filter weather df years to 2000-2020
weather = weather.loc[(weather['year'] >= 2000) & (weather['year'] <= 2020),:]
weather.head()
# Out:
#      year  month  rainy_days  total_rainfall  max_daily_rainfall  mean_rh  \
# 216  2000      1          14           275.2               127.6     86.9
# 217  2000      2          18           237.8                39.9     86.5
# 218  2000      3          15           238.3                37.9     85.8
# 219  2000      4          20           311.6                87.4     85.6
# 220  2000      5          10            96.8                36.7     82.4
#
#      min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# 216            23.9            29.8                4.0           31.8
# 217            23.8            31.0                5.8           32.4
# 218            24.3            31.9                5.8           34.0
# 219            24.6            31.9                5.3           33.4
# 220            25.7            32.7                6.8           34.2
#
#      extr_min_temp  extr_temp_diff  daily_temp_diff
# 216           22.8             9.0              5.9
# 217           21.7            10.7              7.2
# 218           20.2            13.8              7.6
# 219           22.6            10.8              7.3
# 220           22.6            11.6              7.0

# %%
#get a psi df that groups by year, month and get monthly mean
#Calculate average PSI (a way of measuring AQI) from PSI df
mean_monthly = psi.groupby(['year', 'month']).mean()[['north', 'south', 'east', 'west', 'central']]
mean_monthly.reset_index(drop=False, inplace=True)

#Add a column for overall mean psi
mean_monthly['overall_psi'] = (mean_monthly['north']+mean_monthly['south']+mean_monthly['east']+mean_monthly['west']+mean_monthly['central'])/5

# Create new psi indicator column for mean_monthly df
mean_monthly['psi_index'] = mean_monthly['overall_psi'].apply(psi_range)

mean_monthly.tail()
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\403175233.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_monthly = psi.groupby(['year', 'month']).mean()[['north', 'south', 'east', 'west', 'central']]
#     year  month      north      south       east       west    central  \
# 76  2020      8  50.016129  50.071237  49.693548  42.969086  47.098118
# 77  2020      9  48.483333  46.750000  44.966667  40.566667  45.179167
# 78  2020     10  49.677419  51.899194  49.736559  40.405914  47.767473
# 79  2020     11  46.376389  52.230556  46.618056  33.579167  45.476389
# 80  2020     12  42.802419  51.581989  49.846774  33.505376  41.072581
#
#     overall_psi psi_index
# 76    47.969624      Good
# 77    45.189167      Good
# 78    47.897312      Good
# 79    44.856111      Good
# 80    43.761828      Good

# %% [markdown]
# ---
# Merged weather and PSI dataframes, and extract required columns:

# %%
#merge weather_cond with mean_monthly psi df
weather_aqi_psi = pd.merge(left = weather,
                          right = mean_monthly,
                          how = 'left',on=['year', 'month'])

#extract only likely required columns for new table
weather_aqi_psi = weather_aqi_psi[['year', 'month', 'total_rainfall', 'min_daily_temp', 'max_daily_temp', 'extr_max_temp', 'extr_min_temp', 'extr_temp_diff', 'daily_temp_diff', 'overall_psi', 'psi_index']]

weather_aqi_psi.tail()
# Out:
#      year  month  total_rainfall  min_daily_temp  max_daily_temp  \
# 247  2020      8           103.4            25.9            31.4
# 248  2020      9           150.2            24.9            31.0
# 249  2020     10            78.8            25.6            31.6
# 250  2020     11           220.6            25.0            31.0
# 251  2020     12           253.2            24.5            31.5
#
#      extr_max_temp  extr_min_temp  extr_temp_diff  daily_temp_diff  \
# 247           33.0           22.5            10.5              5.5
# 248           33.2           21.9            11.3              6.1
# 249           34.1           22.2            11.9              6.0
# 250           33.4           23.3            10.1              6.0
# 251           33.5           23.0            10.5              7.0
#
#      overall_psi psi_index
# 247    47.969624      Good
# 248    45.189167      Good
# 249    47.897312      Good
# 250    44.856111      Good
# 251    43.761828      Good

# %% [markdown]
# Since PSI data only available from 2014 onwards, lets do a more focused study instead for this segment, and just filter years 2015 to 2020:

# %%
weather_aqi_psi = weather_aqi_psi.loc[(weather_aqi_psi['year'] >= 2015) & (weather_aqi_psi['year'] <= 2020),:]
weather_aqi_psi.reset_index(drop=True, inplace=True)
weather_aqi_psi.head()
# Out:
#    year  month  total_rainfall  min_daily_temp  max_daily_temp  extr_max_temp  \
# 0  2015      1            79.6            24.6            30.7           32.4
# 1  2015      2            18.8            24.4            31.3           33.6
# 2  2015      3            84.4            25.5            32.5           34.4
# 3  2015      4            73.2            25.9            33.2           34.4
# 4  2015      5            89.0            26.4            32.2           34.2
#
#    extr_min_temp  extr_temp_diff  daily_temp_diff  overall_psi psi_index
# 0           23.3             9.1              6.1    48.034409      Good
# 1           23.1            10.5              6.9    50.328869  Moderate
# 2           23.4            11.0              7.0    53.709946  Moderate
# 3           24.0            10.4              7.3    53.437778  Moderate
# 4           24.0            10.2              5.8    49.243011      Good

# %% [markdown]
# ---
# Calculate the percentage where temperature exceeds the overall 20yr mean max_daily temperature of 31.52 degcelc  for each psi_index range:

# %%
#Group by psi_index
grouped_psi_index = weather_aqi_psi.groupby('psi_index')

#define function to get percentage where temperature exceeds the overall 20yr mean max_daily temp in a psi_index range
def exceed_max(index):
    return (len(grouped_psi_index.get_group(index).loc[weather_aqi_psi['max_daily_temp'] > 31.52, :]) / len(weather_aqi_psi['max_daily_temp'])) * 100

#Create loop to count percentage and print percentage
psi_index = ['Good', 'Moderate', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

for index in psi_index:
    try:
        if len(grouped_psi_index.get_group(index)) > 0:
            print(f"The percentage of values for psi_index '{index}' whereby temperature exceeds the overall 20yr mean max_daily temp is: {exceed_max(index):.2f}%")
        else:
            print(f"The percentage of values for psi_index '{index}' whereby temperature exceeds the overall 20yr mean max_daily temp is: 0.00%")
    except:
        print(f"The percentage of values for psi_index '{index}' whereby temperature exceeds the overall 20yr mean max_daily temp is: 0.00%")
# Out:
# The percentage of values for psi_index 'Good' whereby temperature exceeds the overall 20yr mean max_daily temp is: 22.22%
# The percentage of values for psi_index 'Moderate' whereby temperature exceeds the overall 20yr mean max_daily temp is: 34.72%
# The percentage of values for psi_index 'Unhealthy' whereby temperature exceeds the overall 20yr mean max_daily temp is: 2.78%
# The percentage of values for psi_index 'Very Unhealthy' whereby temperature exceeds the overall 20yr mean max_daily temp is: 0.00%
# The percentage of values for psi_index 'Hazardous' whereby temperature exceeds the overall 20yr mean max_daily temp is: 0.00%

# %% [markdown]
# ---
# Calculate the percentage where total rainfall falls below the overall 20yr mean total rainfall of 177.16  for each psi_index range:

# %%
#Group by psi_index
grouped_psi_index = weather_aqi_psi.groupby('psi_index')

#define function to get percentage where temperature exceeds the overall 20yr mean max_daily temp in a psi_index range
def below_mean_rainf(index):
    return (len(grouped_psi_index.get_group(index).loc[weather_aqi_psi['total_rainfall'] > 177.16, :]) / len(weather_aqi_psi['total_rainfall'])) * 100

#Create loop to count percentage and print percentage
psi_index = ['Good', 'Moderate', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

for index in psi_index:
    try:
        if len(grouped_psi_index.get_group(index)) > 0:
            print(f"The percentage of values for psi_index '{index}' whereby total rainfall falls below the overall 20yr mean total rainfall is: {below_mean_rainf(index):.2f}%")
        else:
            print(f"The percentage of values for psi_index '{index}' whereby total rainfall falls below the overall 20yr mean total rainfall is: 0.00%")
    except:
        print(f"The percentage of values for psi_index '{index}' whereby total rainfall falls below the overall 20yr mean total rainfall is: 0.00%")
# Out:
# The percentage of values for psi_index 'Good' whereby total rainfall falls below the overall 20yr mean total rainfall is: 20.83%
# The percentage of values for psi_index 'Moderate' whereby total rainfall falls below the overall 20yr mean total rainfall is: 8.33%
# The percentage of values for psi_index 'Unhealthy' whereby total rainfall falls below the overall 20yr mean total rainfall is: 0.00%
# The percentage of values for psi_index 'Very Unhealthy' whereby total rainfall falls below the overall 20yr mean total rainfall is: 0.00%
# The percentage of values for psi_index 'Hazardous' whereby total rainfall falls below the overall 20yr mean total rainfall is: 0.00%

# %% [markdown]
# Unfortunately, through the above results, we are unable to draw a strong correlation that higher temperatures or lack of rainfall would contribute to a more unhealthy psi index.
# This could be due to a few factors:
# 1) Computation of PSI is based on the 6 different pollutants. Perhaps temperature or rainfall impacts only a few of the pollutants and hence this did not translate in the analysis.
# 2) Measurement of PSI in this project is only available from 2014 onwards (and 2015 to 2020 was used instead). Since the worst haze crisis was in 2013, values of unhealthy and hazardous level PSI were not captured in the analysis.

# %% [markdown]
# ---

# %% [markdown]
# **Observations thus far:**<br>
# * Rainfall is a cyclical / seasonal factor - the hot season with few rainy days and lower total rainfall take place in the earlier half of the year, while the months taking place towards the end of year see more rainy days and higher total rainfall.
# * Temperature and sunshine hours are inversely correlated to the other weather conditions such as relative humidity and rainfall.

# %% [markdown]
# ---

# %% [markdown]
# ## 2.5 Visualize the Data
#
# <details><summary>More details</summary>
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
#     Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.
#     -
#     - Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?</details>

# %% [markdown]
# ---

# %% [markdown]
# ### 2.5.1 Charting the general trend between various weather conditions from 2000 - 2020
# (Rainfall, mean relative humidity, min daily temperature, sunshine duration, etc):

# %%
conditions = weather[['rainy_days', 'total_rainfall', 'max_daily_rainfall', 'mean_rh','min_daily_temp', 'max_daily_temp', 'mean_sunshine_hrs', 'extr_max_temp', 'extr_min_temp', 'extr_temp_diff', 'daily_temp_diff']]
conditions
# Out:
#      rainy_days  total_rainfall  max_daily_rainfall  mean_rh  min_daily_temp  \
# 216          14           275.2               127.6     86.9            23.9
# 217          18           237.8                39.9     86.5            23.8
# 218          15           238.3                37.9     85.8            24.3
# 219          20           311.6                87.4     85.6            24.6
# 220          10            96.8                36.7     82.4            25.7
# ..          ...             ...                 ...      ...             ...
# 463          12           103.4                34.6     76.8            25.9
# 464          18           150.2                32.8     79.0            24.9
# 465          16            78.8                19.0     75.4            25.6
# 466          19           220.6                64.2     81.7            25.0
# 467          20           253.2                58.2     81.1            24.5
#
#      max_daily_temp  mean_sunshine_hrs  extr_max_temp  extr_min_temp  \
# 216            29.8                4.0           31.8           22.8
# 217            31.0                5.8           32.4           21.7
# 218            31.9                5.8           34.0           20.2
# 219            31.9                5.3           33.4           22.6
# 220            32.7                6.8           34.2           22.6
# ..              ...                ...            ...            ...
# 463            31.4                6.4           33.0           22.5
# 464            31.0                4.8           33.2           21.9
# 465            31.6                4.3           34.1           22.2
# 466            31.0                4.0           33.4           23.3
# 467            31.5                5.2           33.5           23.0
#
#      extr_temp_diff  daily_temp_diff
# 216             9.0              5.9
# 217            10.7              7.2
# 218            13.8              7.6
# 219            10.8              7.3
# 220            11.6              7.0
# ..              ...              ...
# 463            10.5              5.5
# 464            11.3              6.1
# 465            11.9              6.0
# 466            10.1              6.0
# 467            10.5              7.0
#
# [252 rows x 11 columns]

# %%
#group by year and get yearly mean for all weather conditions
grouped_year = weather.groupby('year')[['rainy_days', 'total_rainfall', 'max_daily_rainfall', 'mean_rh',
       'min_daily_temp', 'max_daily_temp', 'mean_sunshine_hrs',
       'extr_max_temp', 'extr_min_temp']]
mean_conditions = grouped_year.mean()

#filter to include only 2000-2020
mean_conditions = mean_conditions.loc[(mean_conditions.index >= 2000) & (mean_conditions.index <= 2020),:]
mean_conditions.head()
# Out:
#       rainy_days  total_rainfall  max_daily_rainfall    mean_rh  \
# year
# 2000   15.666667      197.541667           51.308333  84.741667
# 2001   15.333333      231.925000           76.325000  84.266667
# 2002   11.583333      145.741667           47.083333  82.491667
# 2003   15.500000      199.266667           63.275000  84.300000
# 2004   12.250000      178.033333           64.866667  83.466667
#
#       min_daily_temp  max_daily_temp  mean_sunshine_hrs  extr_max_temp  \
# year
# 2000       24.691667       31.408333           5.166667      33.391667
# 2001       24.858333       31.350000           5.216667      33.366667
# 2002       25.241667       32.033333           6.300000      33.658333
# 2003       25.058333       31.433333           5.433333      33.150000
# 2004       25.100000       31.716667           5.966667      33.475000
#
#       extr_min_temp
# year
# 2000      22.416667
# 2001      22.675000
# 2002      23.033333
# 2003      22.775000
# 2004      22.741667

# %%
# Establish the size of the figure.
plt.figure(figsize = (15, 8))

#get iterable list of conditions, create line plot of all mean_conditions conditions
conditions = ['rainy_days', 'total_rainfall', 'max_daily_rainfall', 'mean_rh',
       'min_daily_temp', 'max_daily_temp', 'mean_sunshine_hrs',
       'extr_max_temp', 'extr_min_temp']

for condition in conditions:
    time = mean_conditions.index
    condition_mean = mean_conditions[condition]
    plt.plot(time,
             condition_mean,
             label = condition, marker = 'o');
    
# legend placement on plot
plt.legend(loc = 'upper right', fontsize = 'x-small');

# Create a grid in the background.
plt.grid(True, linewidth = 0.5, linestyle = '--', c = 'black', alpha = 0.2) # recap: alpha-->transparency. 0.1--> 10% opaque


# Create tick mark labels on the X,Y axis without rotating them.
tick_positions = np.arange(2000, 2021, 1)
plt.xticks(tick_positions, fontsize = 10)
plt.yticks(fontsize = 10)

# Create title.
plt.title("Charting yearly mean of various weather conditions", fontsize = 13);

# %% [markdown]
# **FIG 1:** We can see from the above line chart that the various weather conditions are correlated to each other. Total rainfall and max daily rainfall have a stronger correlation, and we can see that line graphs with respect to rainfall are all related.
#
# Mean sunshine hours is inversely correlated to the relative humidity and rainfall.

# %% [markdown]
# **FIG 1:** We can see from the above line chart that the various weather conditions are correlated to each other. Total rainfall and max daily rainfall have an exceptionally strong correlation, and we can see that line graphs with respect to rainfall are all related.
#
# Mean sunshine hours is inversely correlated to the relative humidity and rainfall.

# %% [markdown]
# ---
# ### 2.5.2 Plot heat map for weather condition correlations

# %%
# Establish size of figure.
plt.figure(figsize = (12,7))

# Set up mask to be "True" in the upper triangle.
# because it will be the mirror image of lower triangle we'll see on our plot.
mask = np.zeros_like(weather_cond.corr())
mask[np.triu_indices_from(mask)] = True

# plotting a heatmap with contrasting color scheme
with sns.axes_style("white"):
    sns.heatmap(weather_cond.corr(), mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = 0.5, cmap='coolwarm')
plt.title('Correlation between Weather Conditions');

# %% [markdown]
# **FIG 2:** The heat map shows more clearly the positive and inverse correlations between the weather conditions. As expected, maximum daily rainfall has a strong positive correlation of 0.81 to total rainfall measured; and extreme maximum temperature has a strong correlation of 0.84 to maximum daily temperature.

# %% [markdown]
# ---
# ### 2.5.3 Charting the yearly mean of various air pollutants

# %%
#How do the various air pollutants (that contribute to AQI) relate to each other?
# Establish the size of the figure.
plt.figure(figsize = (15, 8))

#get iterable list of pollutants, create line plot of all air pollutants contributing to AQI
for pollutants in air_qlty:
    pollut_time = air_qlty.index
    pollut_mean = air_qlty[pollutants]
    plt.plot(pollut_time,
             pollut_mean,
             label = pollutants, marker = 'o');
    
# legend placement on plot
plt.legend(loc = 'upper right', fontsize = 'small');

# Create a grid in the background.
plt.grid(True, linewidth = 0.5, linestyle = '--', c = 'black', alpha = 0.2) # recap: alpha-->transparency. 0.1--> 10% opaque


# Create tick mark labels on the X,Y axis without rotating them.
tick_positions = np.arange(2000, 2021, 1)
plt.xticks(tick_positions, fontsize = 10)
plt.yticks(fontsize = 10)

# Create title.
plt.title("Charting yearly mean of various AQI air pollutants", fontsize = 13);

# %% [markdown]
# **FIG 3:** As preliminary investigation, mapping out the yearly mean of the AQI pollutants shows that there is correlation between ozone, pm2.5 and pm10.

# %% [markdown]
# ---
# ### 2.5.4 Charting the yearly mean of air pollutants individually, against Singapore and WHO's air quality targets for year 2020
# The 6 charts above plot the 6 different air pollutants which Singapore uses to measure air quality. Each pollutant is plotted against the Singapore air quality targets for 2020, or WHO's target (only available for sulphur dioxide and PM2.5 pollutants). The blue line in the charts, plot the mean amount of pollutants per year, while the red dotted line shows the target amount.
#
# The rationale behind this visualisation is to get a rough idea of how Singapore fares in terms of controlling the pollutant level that contributes to PSI (Air quality). Pollutants that do not meet these targets should be more heavily monitored, and the NEA taskforce may require the predictive model to account for more buffer time for those pollutants.

# %%
air_qlty.columns
# Out:
# Index(['pm2.5_mean', 'pm10_mean', 'ozone_max_mean', 'lead_mean', 'co_max_mean',
#        'no2_mean', 'so2_mean'],
#       dtype='object')

# %%
import matplotlib.ticker as ticker

#lets chart the yearly mean of air pollutants individually, against Singapore's air quality targets
# Establish figure size.
fig = plt.figure(figsize = (15,17))

# Add the overall title
fig.suptitle('Yearly Mean of Individual Air Pollutants, against targets', fontsize = 18)

# We can create subplots, which allows us to have multiple subplots in the same plot area.
ax1 = plt.subplot(3, 2, 1)
ax1.set_title('Sulphur Dioxide (SO2)')
plt.plot(air_qlty.index,
         air_qlty['so2_mean'],
         label = pollutants, marker = 'o');
ax1.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax1.axhline(y=25, color='red', linestyle='--')

ax2 = plt.subplot(3, 2, 2)
ax2.set_title('Particulate Matter (PM2.5)')
plt.plot(air_qlty.index,
         air_qlty['pm2.5_mean'],
         label = pollutants, marker = 'o');
ax2.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax2.axhline(y=10, color='red', linestyle='--')

ax3 = plt.subplot(3, 2, 3)
ax3.set_title('Particulate Matter (PM10)')
plt.plot(air_qlty.index,
         air_qlty['pm10_mean'],
         label = pollutants, marker = 'o');
ax3.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax3.axhline(y=50, color='red', linestyle='--')

ax4 = plt.subplot(3, 2, 4)
ax4.set_title('Ozone')
plt.plot(air_qlty.index,
         air_qlty['ozone_max_mean'],
         label = pollutants, marker = 'o');
ax4.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax4.axhline(y=100, color='red', linestyle='--')

ax5 = plt.subplot(3, 2, 5)
ax5.set_title('Nitrogen Dioxide (NO2)')
plt.plot(air_qlty.index,
         air_qlty['no2_mean'],
         label = pollutants, marker = 'o');
ax5.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax5.axhline(y=40, color='red', linestyle='--')

ax6 = plt.subplot(3, 2, 6)
ax6.set_title('Carbon Monoxide (CO)')
plt.plot(air_qlty.index,
         air_qlty['co_max_mean'],
         label = pollutants, marker = 'o');
ax6.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax6.axhline(y=30, color='red', linestyle='--')

# Adjust the spacing between subplots
fig.tight_layout()

# %% [markdown]
# **FIG 4:** Surprisingly, PM2.5 and PM10 do not meet the target. These pollutants should hence be more heavily monitored when developing an air quality monitoring system, and the NEA taskforce may require the predictive model to account for more buffer time when predicting deterioration of these pollutants. This is to ensure ample measures can be put in place to control pollution levels.

# %% [markdown]
# ---
# ### 2.5.5 Plot correlation chart between all weather conditions and air pollutants

# %%
#First, merge weather_cond df with air_qlty df
weather_aqi = pd.merge(left = weather_cond,
                          right = air_qlty,
                          how = 'left',left_index=True, right_index=True)
weather_aqi.head()
# Out:
#       rainy_days  total_rainfall  max_daily_rainfall  mean_rh  min_daily_temp  \
# year
# 1982          10           107.1                36.5     81.2            23.3
# 1982           5            27.8                 9.4     79.5            23.9
# 1982          11           160.8                61.7     82.3            24.3
# 1982          14           157.0                45.1     85.9            24.3
# 1982          10           102.2                33.0     83.2            25.2
#
#       max_daily_temp  mean_sunshine_hrs  extr_max_temp  extr_min_temp  \
# year
# 1982            29.8                5.6           31.9           21.9
# 1982            32.3                7.6           34.3           22.6
# 1982            31.7                5.1           34.3           22.3
# 1982            31.4                4.7           33.2           22.2
# 1982            31.7                5.8           32.9           23.7
#
#       pm2.5_mean  pm10_mean  ozone_max_mean  lead_mean  co_max_mean  no2_mean  \
# year
# 1982         NaN        NaN             NaN        NaN          NaN       NaN
# 1982         NaN        NaN             NaN        NaN          NaN       NaN
# 1982         NaN        NaN             NaN        NaN          NaN       NaN
# 1982         NaN        NaN             NaN        NaN          NaN       NaN
# 1982         NaN        NaN             NaN        NaN          NaN       NaN
#
#       so2_mean
# year
# 1982       NaN
# 1982       NaN
# 1982       NaN
# 1982       NaN
# 1982       NaN

# %%
#find correlation between all weather conditions and pollutants in AQI
weather_aqi.corr()
# Out:
#                     rainy_days  total_rainfall  max_daily_rainfall   mean_rh  \
# rainy_days            1.000000        0.684252            0.396088  0.582346
# total_rainfall        0.684252        1.000000            0.810002  0.592447
# max_daily_rainfall    0.396088        0.810002            1.000000  0.438402
# mean_rh               0.582346        0.592447            0.438402  1.000000
# min_daily_temp       -0.320566       -0.463821           -0.364366 -0.638091
# max_daily_temp       -0.472289       -0.572425           -0.440159 -0.567153
# mean_sunshine_hrs    -0.679018       -0.575614           -0.387892 -0.594081
# extr_max_temp        -0.288046       -0.389725           -0.299722 -0.439883
# extr_min_temp        -0.234252       -0.295437           -0.256298 -0.275903
# pm2.5_mean           -0.145909        0.029871            0.081412  0.236634
# pm10_mean            -0.071616       -0.014543           -0.037618 -0.196164
# ozone_max_mean        0.085846        0.051566            0.014436  0.097034
# lead_mean                  NaN             NaN                 NaN       NaN
# co_max_mean           0.053435        0.127146            0.141149  0.165506
# no2_mean              0.062182        0.054569            0.050847  0.220390
# so2_mean              0.046181        0.118590            0.145847  0.340088
#
#                     min_daily_temp  max_daily_temp  mean_sunshine_hrs  \
# rainy_days               -0.320566       -0.472289          -0.679018
# total_rainfall           -0.463821       -0.572425          -0.575614
# max_daily_rainfall       -0.364366       -0.440159          -0.387892
# mean_rh                  -0.638091       -0.567153          -0.594081
# min_daily_temp            1.000000        0.681289           0.420534
# max_daily_temp            0.681289        1.000000           0.612172
# mean_sunshine_hrs         0.420534        0.612172           1.000000
# extr_max_temp             0.535414        0.840161           0.380067
# extr_min_temp             0.451549        0.429629           0.264387
# pm2.5_mean               -0.071244        0.053852           0.026130
# pm10_mean                 0.114702        0.047014           0.042069
# ozone_max_mean           -0.064634       -0.160486          -0.056231
# lead_mean                      NaN             NaN                NaN
# co_max_mean              -0.106342       -0.036241          -0.108773
# no2_mean                 -0.105213       -0.017337          -0.060452
# so2_mean                 -0.188346       -0.061743          -0.131717
#
#                     extr_max_temp  extr_min_temp  pm2.5_mean  pm10_mean  \
# rainy_days              -0.288046      -0.234252   -0.145909  -0.071616
# total_rainfall          -0.389725      -0.295437    0.029871  -0.014543
# max_daily_rainfall      -0.299722      -0.256298    0.081412  -0.037618
# mean_rh                 -0.439883      -0.275903    0.236634  -0.196164
# min_daily_temp           0.535414       0.451549   -0.071244   0.114702
# max_daily_temp           0.840161       0.429629    0.053852   0.047014
# mean_sunshine_hrs        0.380067       0.264387    0.026130   0.042069
# extr_max_temp            1.000000       0.356748    0.009336   0.099404
# extr_min_temp            0.356748       1.000000   -0.031279  -0.028076
# pm2.5_mean               0.009336      -0.031279    1.000000   0.497192
# pm10_mean                0.099404      -0.028076    0.497192   1.000000
# ozone_max_mean          -0.072067      -0.031542   -0.110449  -0.038183
# lead_mean                     NaN            NaN         NaN        NaN
# co_max_mean              0.055118      -0.141309    0.542993   0.634654
# no2_mean                 0.011478      -0.129804    0.262327  -0.067562
# so2_mean                -0.034324      -0.118484    0.641817   0.013920
#
#                     ozone_max_mean  lead_mean  co_max_mean  no2_mean  so2_mean
# rainy_days                0.085846        NaN     0.053435  0.062182  0.046181
# total_rainfall            0.051566        NaN     0.127146  0.054569  0.118590
# max_daily_rainfall        0.014436        NaN     0.141149  0.050847  0.145847
# mean_rh                   0.097034        NaN     0.165506  0.220390  0.340088
# min_daily_temp           -0.064634        NaN    -0.106342 -0.105213 -0.188346
# max_daily_temp           -0.160486        NaN    -0.036241 -0.017337 -0.061743
# mean_sunshine_hrs        -0.056231        NaN    -0.108773 -0.060452 -0.131717
# extr_max_temp            -0.072067        NaN     0.055118  0.011478 -0.034324
# extr_min_temp            -0.031542        NaN    -0.141309 -0.129804 -0.118484
# pm2.5_mean               -0.110449        NaN     0.542993  0.262327  0.641817
# pm10_mean                -0.038183        NaN     0.634654 -0.067562  0.013920
# ozone_max_mean            1.000000        NaN    -0.257610 -0.329993 -0.180551
# lead_mean                      NaN        NaN          NaN       NaN       NaN
# co_max_mean              -0.257610        NaN     1.000000  0.451615  0.658619
# no2_mean                 -0.329993        NaN     0.451615  1.000000  0.752539
# so2_mean                 -0.180551        NaN     0.658619  0.752539  1.000000

# %% [markdown]
# After seeing the correlation table, I decided on 2 more steps that could help me achieve clearer visualisation:
# 1. To drop lead_mean from the dataframe. As mean lead amounts were constantly <0.1 for all years, and there would be no point including it.
# 2. Perhaps i should not find correlation of all factors (for both weather and AQI) on a 12x12 heatmap. I could measure weather conditions on one axis against pollutants on another axis, on a 6x5 heatmap.

# %%
#drop lead_mean from weather_aqi
air_qlty_no_lead = air_qlty.drop(columns=['lead_mean'])
air_qlty_no_lead.head()
# Out:
#       pm2.5_mean  pm10_mean  ozone_max_mean  co_max_mean  no2_mean  so2_mean
# year
# 2000         NaN       64.0           112.0          3.7      30.0      22.0
# 2001         NaN       56.0           133.0          4.2      26.0      22.0
# 2002        23.0       72.0           131.0          2.7      27.0      18.0
# 2003        19.0       52.0           118.0          3.2      24.0      15.0
# 2004        21.0       60.0           146.0          2.8      26.0      14.0

# %%
#Plot weather conditions on one axis against pollutants on another axis, on a 6x5 heatmap
# Establish size of figure.
plt.figure(figsize = (12,7));

# Calculate correlation matrix
corr_matrix = pd.concat([weather_cond, air_qlty_no_lead], axis=1).corr()

# Plot correlation heatmap
fig, ax = plt.subplots();
sns.heatmap(corr_matrix.iloc[:len(weather_cond.columns), len(weather_cond.columns):], annot=True, cmap='coolwarm', ax=ax, vmin = -0.35, vmax = 0.35,linewidths = 0.5);

# Set x-axis and y-axis labels
ax.set_xticklabels(air_qlty_no_lead.columns, rotation=90, fontsize = 8);
ax.set_yticklabels(weather_cond.columns, rotation=0, fontsize = 8);

# Set plot title
plt.title('Correlation Between Weather Conditions vs Air Pollutants');

# %% [markdown]
# **FIG 5:** From the above correlation heatmap, correlation is not strong. This may not be most accurate, since the data we are measuring is only looking at yearly mean values.
# Stronger correlations are between mean relative humidity to sulfur dioxide mean.

# %% [markdown]
# ---
# ### 2.5.6 Plotting heatmap for seasonal trends in temperature, by months of the year

# %%
#Is there any seasonal trend for temperature if we analyse by months of the year?
#use heat map - plot min daily temp

#extract required columns
heatmap_min_daily_temp = weather[['year', 'month', 'min_daily_temp']]
heatmap_min_daily_temp.head()
# Out:
#      year  month  min_daily_temp
# 216  2000      1            23.9
# 217  2000      2            23.8
# 218  2000      3            24.3
# 219  2000      4            24.6
# 220  2000      5            25.7

# %%
#pivot to plot year on x axis, month on y-axis
heatmap_min_daily_temp_pivot = heatmap_min_daily_temp.pivot('month', 'year', 'min_daily_temp')
heatmap_min_daily_temp_pivot.head()
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\1194447011.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   heatmap_min_daily_temp_pivot = heatmap_min_daily_temp.pivot('month', 'year', 'min_daily_temp')
# year   2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  ...  2011  \
# month                                                              ...
# 1      23.9  24.0  24.5  24.4  24.2  23.9  24.1  24.2  24.3  24.2  ...  23.5
# 2      23.8  24.5  24.5  24.4  24.7  25.3  24.8  24.5  24.0  24.2  ...  24.1
# 3      24.3  24.2  25.1  25.2  24.7  25.4  25.2  24.6  24.0  24.1  ...  23.9
# 4      24.6  25.1  25.6  25.3  26.1  25.7  24.8  25.2  25.1  25.4  ...  24.6
# 5      25.7  25.7  26.1  26.5  26.4  25.2  25.4  25.3  26.0  25.3  ...  25.2
#
# year   2012  2013  2014  2015  2016  2017  2018  2019  2020
# month
# 1      24.3  24.6  24.0  24.6  26.0  24.7  24.0  25.6  25.2
# 2      24.8  24.3  24.5  24.4  25.6  24.7  24.8  25.4  25.3
# 3      24.4  25.6  25.1  25.5  26.6  24.9  25.4  25.6  25.9
# 4      24.8  25.3  25.5  25.9  26.7  25.0  25.8  25.9  26.0
# 5      24.8  25.6  25.8  26.4  26.5  25.9  26.2  26.5  26.1
#
# [5 rows x 21 columns]

# %%
#use heat map - plot min daily temp

#extract required columns
heatmap_max_daily_temp = weather[['year', 'month', 'max_daily_temp']]
heatmap_max_daily_temp.head()

#pivot to plot year on x axis, month on y-axis
heatmap_max_daily_temp_pivot = heatmap_max_daily_temp.pivot('month', 'year', 'max_daily_temp')
heatmap_max_daily_temp_pivot.head()
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\453338062.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   heatmap_max_daily_temp_pivot = heatmap_max_daily_temp.pivot('month', 'year', 'max_daily_temp')
# year   2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  ...  2011  \
# month                                                              ...
# 1      29.8  30.3  30.9  30.1  30.6  30.2  30.0  29.8  30.7  30.7  ...  29.7
# 2      31.0  30.9  31.3  30.8  32.0  33.4  31.5  31.5  30.9  32.3  ...  31.7
# 3      31.9  31.8  33.0  32.3  32.2  33.3  33.1  31.5  30.1  31.4  ...  31.3
# 4      31.9  31.8  33.0  32.1  33.3  33.0  32.1  32.0  31.9  32.3  ...  31.9
# 5      32.7  32.2  32.6  32.7  32.8  32.4  32.0  31.6  32.2  32.2  ...  32.4
#
# year   2012  2013  2014  2015  2016  2017  2018  2019  2020
# month
# 1      30.6  30.8  29.6  30.7  31.8  30.7  29.8  31.7  31.7
# 2      31.1  30.1  31.9  31.3  31.1  30.7  31.2  32.8  31.7
# 3      31.1  32.4  32.8  32.5  33.1  31.1  32.4  33.5  32.9
# 4      31.4  32.1  32.4  33.2  33.4  31.8  33.2  32.7  33.0
# 5      31.7  31.8  32.1  32.2  33.0  31.4  32.4  32.7  32.2
#
# [5 rows x 21 columns]

# %%
#plot a heatmap each, for min and max daily temp
fig, axs = plt.subplots(1, 2, figsize=(25, 10), sharey=True)

ax1 = sns.heatmap(heatmap_min_daily_temp_pivot,
    linewidths=0.5,
    cmap="rocket_r",
    center=26,
    ax=axs[0]
    )
ax1.set_title('Mean Minimum Daily Temperatures', fontsize=14);
ax2 = sns.heatmap(heatmap_max_daily_temp_pivot,
    linewidths=0.5,
    cmap="rocket_r",
    center=32,
    ax=axs[1]
    )
ax2.set_title('Mean Maximum Daily Temperatures', fontsize=14);
fig.suptitle("Heatmap Charting Temperatures", fontsize=17)
axs[0].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=12)
axs[1].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=12)
axs[0].set_ylabel("Month", fontsize=9)
axs[1].set_ylabel("Month", fontsize=9)
plt.show()

# %% [markdown]
# **FIG 6:** From both charts, we can see that both the min daily temperatures and max daily temperatures have been increasing over the years. This is possibly due to global warming, as we face rising temperatures.<br>
# From the max daily temperature heatmap, we can see that temperatures are hottest in the period of February to June. From the min daily temperature heatmap, we can see temperatures are cooler in the months of November, December and January.

# %% [markdown]
# ---
# ### 2.5.7 Time Decomposition Charts to analyse seasonality

# %%
#analyse for seasonality - compare rainfall and max daily temperature

#dataframe for rainfall
rainfall_df = weather[['year', 'month', 'total_rainfall']]

# %%
#create time decomposition chart for max daily temp
from statsmodels.tsa.seasonal import seasonal_decompose

# Convert 'year' and 'month' columns to datetime format
heatmap_max_daily_temp['date'] = pd.to_datetime(heatmap_max_daily_temp[['year', 'month']].assign(day=1))

# Set the 'date' column as the index
heatmap_max_daily_temp.set_index('date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(heatmap_max_daily_temp['max_daily_temp'], model='multiplicative')

# Plot the decomposition
decomposition.plot()
plt.show()
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\1362697389.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heatmap_max_daily_temp['date'] = pd.to_datetime(heatmap_max_daily_temp[['year', 'month']].assign(day=1))

# %%
#create time decomposition chart for rainfall
from statsmodels.tsa.seasonal import seasonal_decompose

# Convert 'year' and 'month' columns to datetime format
rainfall_df['date'] = pd.to_datetime(rainfall_df[['year', 'month']].assign(day=1))

# Set the 'date' column as the index
rainfall_df.set_index('date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(rainfall_df['total_rainfall'], model='multiplicative')

# Plot the decomposition
decomposition.plot()
plt.show()
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_1560\837997451.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rainfall_df['date'] = pd.to_datetime(rainfall_df[['year', 'month']].assign(day=1))

# %% [markdown]
# **FIG 7, FIG 8:** From the 2 charts above, we can conclude that maximum daily temp and total rainfall is seasonal.
# Maximum daily temperature gradually increases over time, while total rainfall falls.

# %% [markdown]
# ---

# %% [markdown]
# ## 2.6 Conclusions and Recommendations

# %% [markdown]
# Some key takeaways and recommendations
#
# * We can see the effects of global warming in the graphs, with temperatures generally rising, and total rainfall amounts falling over time.
# * From the research done, theory tells us it is likely possible that decreased rainfall, and hotter temperatures should lead to deterioration of air quality. However, our EDA findings tell us that correlation is not strong, and more in depth analysis would have to be done in order to gain more insights. Majority of the pollutant datasets only provide a yearly mean, so data was of lower granularity. For greater accuracy in developing the air quality early warning system, we recommend for data of higher granularity to be used.
# * Temperature and rainfall are seasonal variables, and the seasonality remains quite stable over time for the Singapore context. Considering we would like to develop a set of air quality early warning systems to predict air quality, it is a good sign that weather conditions are generally stable, so that any variations would be able to serve as an alert to prepare for potential air quality changes.
# * Relative humidity seems to have the strongest correlation to the various pollutants, so this relationship should be further explored for the modelling and prediction stage.
#
# It is also important to note that while our focus is currently on weather and its impact on air quality, we would need to consider several other factors in order to develop a comprehensive air quality early warning system. Other factors would include:
# * Emissions from human activities - Industrial plants, transportation, etc.
# * Natural sources of pollution (volcanic eruptions, wildfires, etc) from our surrounding countries leading to transboundary haze
